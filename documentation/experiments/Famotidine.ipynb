# %% [markdown]
# # Famotidine Covid
#
# This is a test case to see whether Answer Merging helps with the arbitrary query problem. The problem is: I want to know the most interesting way in which these two entities are related.  What is it?  One option is to do question rewriting.  But another (this one) is to general queries and then work on merging them.

# %%
import requests
import json
import time
import pandas as pd

#GammaViewer available from https://github.com/ranking-agent/gamma-viewer
from GammaViewer import GammaViewer
from IPython.display import display

# %%
def getlabel(curie):
    url = 'https://nodenormalization-sri.renci.org/get_normalized_nodes'
    try:
        r = requests.get(url,params={'curie':curie}).json()
        return r[curie]['id']['label']
    except:
        return ''

class RobokopMessenger:
    def __init__(self):
        self.url = 'https://covidkop.renci.org/messenger'
    def pipeline(self,request,full = True):
        #normalize question
        purl = f'{self.url}/normalize'
        print(purl)
        response = requests.post( purl , json=request )
        normalized = response.json()
        
        #answer question
        request = { 'message': normalized, }
        response = requests.post( f'{self.url}/answer', json=request )
        answered = response.json()
        if not full:
            return answered
        
        #Yank
        request = { 'message': answered, }
        response = requests.post( f'{self.url}/yank', json=request )
        filled = response.json()
        
        #support
        request = { 'message': filled, }
        response = requests.post( 'http://robokop.renci.org:4868/support', json=request )
        supported = response.json()
        #weight
        request = { 'message': supported, }
        response = requests.post( 'http://robokop.renci.org:4868/weight_correctness', json=request )
        weighted = response.json()
        #score
        request = { 'message': weighted, }
        response = requests.post( 'http://robokop.renci.org:4868/score', json=request )
        scored = response.json()
        return scored

    
robokop=RobokopMessenger()

# %%
def create_message():
    query_graph = {
    "nodes": [
        {
            #Covid-19
            "id": "a",
            "type": "disease",
            "curie": "MONDO:0100096"
        },
        {
            "id": "b",
            "type": "named_thing"
        },
        {
            #Famotidine
            "id": "c",
            "type": "chemical_substance",
            "curie": "CHEBI:4975"
        }
    ],
    "edges": [
        {
            "id": "ab",
            "source_id": "a",
            "target_id": "b"
        },
        {
            "id": "bc",
            "source_id": "c",
            "target_id": "b"
        }
    ]
    }
    message = {"message": {"query_graph": query_graph,
                           'results':[{"node_bindings": [],"edge_bindings": []}]}}
    return message

# %%
message = create_message()
react_component = GammaViewer(props={"data":message['message']})
display(react_component)

# %%
robokop_result = robokop.pipeline(message,full=False)
print( json.dumps(robokop_result,indent=2))
# Out:
# https://covidkop.renci.org/messenger/normalize
# {
#   "query_graph": {
#     "nodes": [
#       {
#         "id": "a",
#         "curie": [
#           "MONDO:0100096"
#         ],
#         "type": "disease"
#       },
#       {
#         "id": "b",
#         "curie": null,
#         "type": "named_thing"
#       },
#       {
#         "id": "c",
#         "curie": [
#           "CHEBI:4975"
#         ],
#         "type": "chemical_substance"
#       }
#     ],
#     "edges": [
#       {
#         "id": "ab",
#         "source_id": "a",
#         "target_id": "b",
#         "type": null
#       },
#       {
#         "id": "bc",
#         "source_id": "c",
#         "target_id": "b",
#         "type": null
#       }
#     ]
#   },
#   "knowledge_graph": {
#     "nodes": [
#       {
#         "id": "MONDO:0100096",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "SNOMEDCT:840539006",
#           "MONDO:0100096",
#           "DOID:0080600"
#         ],
#         "name": "COVID-19"
#       },
#       {
#         "id": "NCBITaxon:2697049",
#         "type": [
#           "named_thing",
#           "ontology_class",
#           "organism_taxon"
#         ],
#         "equivalent_identifiers": [
#           "NCBITaxon:2697049",
#           "MESH:C000656484"
#         ],
#         "name": "Severe acute respiratory syndrome coronavirus 2"
#       },
#       {
#         "id": "CHEBI:4975",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "chemical_substance",
#           "molecular_entity"
#         ],
#         "synonyms": [
#           "N'-(aminosulfonyl)-3-[({2-[(diaminomethylidene)amino]-1,3-thiazol-4-yl}methyl)sulfanyl]propanimidamide",
#           "(1-Amino-3-(((2-((diaminomethylene)amino)-4-thiazolyl)methyl)thio)propylidene)sulfamide",
#           "3-(((2-((Aminoiminomethyl)amino)-4-thiazolyl)methyl)thio)-N-(aminosulfonyl)propanimidamide",
#           "3-(((2-((Diaminomethylene)amino)-4-thiazolyl)methyl)thio)-N(sup 2)-sulfamoylpropionamidine",
#           "famotidina",
#           "famotidine",
#           "famotidinum",
#           "N-Sulfamoyl-3-((2-guanidinothiazol-4-yl)methylthio)propionamide",
#           "Pepcid"
#         ],
#         "withdrawn_flag": false,
#         "biochemical_role": true,
#         "neurotransmitter_agent": true,
#         "EC_1.14.14.1_(unspecific_monooxygenase)_inhibitor": true,
#         "H2_receptor_antagonist": true,
#         "EC_1.14.14.*_(oxidoreductase_acting_on_paired_donors__incorporating_of_1_atom_of_oxygen__with_reduced_flavin_or_flavoprotein_as_one_donor)_inhibitor": true,
#         "histaminergic_drug": true,
#         "role": true,
#         "inhibitor": true,
#         "application": true,
#         "enzyme_inhibitor": true,
#         "oral": true,
#         "name": "famotidine",
#         "parenteral": true,
#         "prodrug": 0,
#         "pharmacological_role": true,
#         "histamine_antagonist": true,
#         "EC_1.*_(oxidoreductase)_inhibitor": true,
#         "pharmaceutical": true,
#         "drugbank.accession_number": "APRD00296",
#         "drugbank.categories": [
#           "Acid Reducers",
#           "Alimentary Tract and Metabolism",
#           "Anti-Ulcer Agents",
#           "Drugs for Acid Related Disorders",
#           "Drugs for Peptic Ulcer and Gastro-Oesophageal Reflux Disease (Gord)",
#           "Gastric Acid Lowering Agents",
#           "Gastrointestinal Agents",
#           "Histamine Agents",
#           "Histamine Antagonists",
#           "Histamine H2 Antagonists",
#           "Neurotransmitter Agents",
#           "OAT3/SLC22A8 Inhibitors",
#           "OAT3/SLC22A8 Substrates",
#           "OCT2 Inhibitors",
#           "Potential QTc-Prolonging Agents",
#           "QTc Prolonging Agents",
#           "Sulfur Compounds",
#           "Thiazoles"
#         ],
#         "drugbank.approved": true,
#         "natural_product": 1,
#         "P450_inhibitor": true,
#         "therapeutic_flag": true,
#         "drug": true,
#         "equivalent_identifiers": [
#           "PUBCHEM.COMPOUND:5353622",
#           "INCHIKEY:NJTQENWDJVHUOX-GXDHUFHOSA-N",
#           "UNII:5QZO15J2Z8",
#           "MESH:D015738",
#           "gtpo:7074",
#           "PUBCHEM.COMPOUND:5702160",
#           "DRUGBANK:DB00927",
#           "PUBCHEM.COMPOUND:3325",
#           "CHEMBL.COMPOUND:CHEMBL902",
#           "CHEBI:4975",
#           "HMDB:HMDB0001919"
#         ],
#         "molecule_type": "Small molecule",
#         "topical": false,
#         "molecule_properties": "{'alogp': '-0.77', 'aromatic_rings': 1, 'cx_logd': '-2.67', 'cx_logp': '-1.95', 'cx_most_apka': '9.29', 'cx_most_bpka': '8.38', 'full_molformula': 'C8H15N7O2S3', 'full_mwt': '337.46', 'hba': 6, 'hba_lipinski': 9, 'hbd': 4, 'hbd_lipinski': 8, 'heavy_atoms': 20, 'molecular_species': 'NEUTRAL', 'mw_freebase': '337.46', 'mw_monoisotopic': '337.0449', 'num_lipinski_ro5_violations': 1, 'num_ro5_violations': 0, 'psa': '175.83', 'qed_weighted': '0.29', 'ro3_pass': 'N', 'rtb': 7}",
#         "antagonist": true,
#         "EC_1.14.*_(oxidoreductase_acting_on_paired_donors__with_incorporation_or_reduction_of_molecular_oxygen)_inhibitor": true,
#         "anti_ulcer_drug": true,
#         "biological_role": true
#       },
#       {
#         "id": "MONDO:0056821",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [
#           "organized pneumonia",
#           "BOOP",
#           "constrictive bronchiolitis",
#           "organizing pneumonia"
#         ],
#         "equivalent_identifiers": [
#           "SNOMEDCT:68409003",
#           "MONDO:0056821",
#           "UMLS:C2747929",
#           "UMLS:C0264383",
#           "MEDDRA:10067472"
#         ],
#         "name": "bronchiolitis obliterans organizing pneumonia"
#       },
#       {
#         "id": "MONDO:0019737",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "UMLS:C2717961",
#           "MESH:D057049",
#           "SNOMEDCT:126729006",
#           "MONDO:0019737",
#           "ORPHANET:93573",
#           "MEDDRA:10043645",
#           "NCIT:C62605"
#         ],
#         "name": "thrombotic microangiopathy"
#       },
#       {
#         "id": "MONDO:0015796",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "MEDDRA:10069351",
#           "NCIT:C155766",
#           "SNOMEDCT:315345002",
#           "EFO:0004610",
#           "MESH:D055371",
#           "UMLS:C0242488",
#           "ORPHANET:178320",
#           "MONDO:0015796"
#         ],
#         "name": "acute lung injury"
#       },
#       {
#         "id": "NCBIGene:7124",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "molecular_entity",
#           "gene",
#           "gene_or_gene_product",
#           "macromolecular_machine",
#           "genomic_entity"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "HGNC:11892",
#           "NCBIGene:7124",
#           "UniProtKB:P01375",
#           "NCBIGene:7124",
#           "ENSEMBL:ENSG00000232810"
#         ],
#         "description": "tumor necrosis factor [Source:HGNC Symbol;Acc:HGNC:11892]",
#         "gene_family_id": [
#           781
#         ],
#         "gene_family": [
#           "Tumor necrosis factor superfamily"
#         ],
#         "location": "6p21.33",
#         "start_position": 31575565,
#         "chromosome": "6",
#         "gene_biotype": "protein_coding",
#         "ensembl_name": "TNF",
#         "end_position": 31578336,
#         "taxon": 9606,
#         "locus_group": "protein-coding gene",
#         "name": "TNF"
#       },
#       {
#         "id": "MONDO:0005478",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "MONDO:0005478",
#           "MESH:D016171",
#           "MEDDRA:10044066",
#           "UMLS:C1328584",
#           "HP:0001664",
#           "NCIT:C50779",
#           "SNOMEDCT:31722008",
#           "UMLS:C0040479"
#         ],
#         "name": "torsades de pointes"
#       },
#       {
#         "id": "MONDO:0004652",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "MESH:D018410",
#           "EFO:1001272",
#           "DOID:874",
#           "UMLS:C2189270",
#           "UMLS:C4727977",
#           "MEDDRA:10060946",
#           "SNOMEDCT:53084003",
#           "UMLS:C0375327",
#           "NCIT:C26704",
#           "UMLS:C4727975",
#           "UMLS:C0004626",
#           "MONDO:0004652",
#           "UMLS:C4727976"
#         ],
#         "name": "bacterial pneumonia"
#       },
#       {
#         "id": "MONDO:0002258",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "MEDDRA:10043521",
#           "SNOMEDCT:405737000",
#           "UMLS:C0031350",
#           "SNOMEDCT:162400007",
#           "UMLS:C3854543",
#           "UMLS:C0858940",
#           "SNOMEDCT:284207003",
#           "UMLS:C0242429",
#           "UMLS:C0241381",
#           "UMLS:C0863112",
#           "UMLS:C0858941",
#           "MONDO:0002258",
#           "UMLS:C4087337",
#           "UMLS:C2363731",
#           "UMLS:C0542075",
#           "SNOMEDCT:162397003",
#           "UMLS:C0562057",
#           "UMLS:C3854544",
#           "DOID:2275",
#           "UMLS:C0858938",
#           "MESH:D010612",
#           "MEDDRA:10068319",
#           "NCIT:C50747",
#           "UMLS:C0700184",
#           "NCIT:C26851"
#         ],
#         "name": "pharyngitis"
#       },
#       {
#         "id": "MONDO:0001208",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [
#           "acute respiratory failure",
#           "respiratory failure, acute"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C4285915",
#           "SNOMEDCT:65710008",
#           "MEDDRA:10001053",
#           "UMLS:C0748352",
#           "MONDO:0001208",
#           "NCIT:C27043",
#           "SNOMEDCT:67905004",
#           "UMLS:C0865850",
#           "UMLS:C0264490",
#           "UMLS:C0264491"
#         ],
#         "acute_disease": true,
#         "name": "acute respiratory failure"
#       },
#       {
#         "id": "MONDO:0045057",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [
#           "organic brain syndrome"
#         ],
#         "equivalent_identifiers": [
#           "NCIT:C121627",
#           "UMLS:C3203501",
#           "UMLS:C0683369",
#           "SNOMEDCT:40917007",
#           "SNOMEDCT:112077003",
#           "NCIT:C37928",
#           "SNOMEDCT:231440006",
#           "MESH:D003221",
#           "UMLS:C0813178",
#           "UMLS:C3203503",
#           "UMLS:C0857386",
#           "UMLS:C0338642",
#           "UMLS:C1306588",
#           "UMLS:C0751054",
#           "SNOMEDCT:191492000",
#           "MEDDRA:10012219",
#           "UMLS:C0858855",
#           "UMLS:C0154596",
#           "UMLS:C0152124",
#           "UMLS:C0154333",
#           "MEDDRA:10010305",
#           "UMLS:C0422893",
#           "MEDDRA:10013395",
#           "EFO:0009267",
#           "SNOMEDCT:2776000",
#           "NCIT:C92639",
#           "UMLS:C0860621",
#           "SNOMEDCT:231439009",
#           "UMLS:C0029221",
#           "UMLS:C0235071",
#           "UMLS:C0011206",
#           "MEDDRA:10012373",
#           "NCIT:C78253",
#           "MESH:D003244",
#           "UMLS:C0549249",
#           "SNOMEDCT:40673001",
#           "NCIT:C2981",
#           "UMLS:C0234983",
#           "UMLS:C0542207",
#           "UMLS:C0233407",
#           "SNOMEDCT:191678001",
#           "NCIT:C34868",
#           "UMLS:C0751053",
#           "UMLS:C0860623",
#           "UMLS:C0009792",
#           "UMLS:C1142436",
#           "UMLS:C0041862",
#           "UMLS:C0338644",
#           "UMLS:C0860622",
#           "SNOMEDCT:286933003",
#           "UMLS:C0858851",
#           "UMLS:C0859069",
#           "UMLS:C0235070",
#           "SNOMEDCT:62476001",
#           "UMLS:C0541890",
#           "UMLS:C1142529",
#           "MESH:D003693",
#           "MEDDRA:10031077",
#           "UMLS:C0856071",
#           "UMLS:C0877609",
#           "UMLS:C0751055",
#           "UMLS:C0338664",
#           "UMLS:C0009676",
#           "SNOMEDCT:609585002",
#           "MEDDRA:10012218",
#           "UMLS:C0154326",
#           "HP:0001289",
#           "UMLS:C0877450",
#           "UMLS:C1285577",
#           "UMLS:C1737242",
#           "UMLS:C3203502",
#           "UMLS:C0857152",
#           "UMLS:C0857042",
#           "UMLS:C4285867",
#           "MONDO:0045057"
#         ],
#         "psychiatric_disorder": true,
#         "name": "delirium"
#       },
#       {
#         "id": "MONDO:0005249",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "SNOMEDCT:233604007",
#           "UMLS:C3714636",
#           "MONDO:0005249",
#           "HP:0002090",
#           "MESH:D011014",
#           "UMLS:C0887898",
#           "UMLS:C2074898",
#           "UMLS:C0032285",
#           "NCIT:C3333",
#           "EFO:0003106",
#           "MEDDRA:10035742",
#           "DOID:552"
#         ],
#         "name": "pneumonia"
#       },
#       {
#         "id": "MONDO:0003785",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "MESH:D007970",
#           "UMLS:C0023530",
#           "MEDDRA:10024384",
#           "DOID:615",
#           "MONDO:0003785",
#           "HP:0001882",
#           "EFO:0004233",
#           "NCIT:C26816",
#           "SNOMEDCT:84828003"
#         ],
#         "name": "leukopenia"
#       },
#       {
#         "id": "MONDO:0005252",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [
#           "cardiac failure",
#           "cardiac insufficiency",
#           "failure, heart",
#           "heart failure",
#           "insufficiency, Cardiac"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C1959583",
#           "UMLS:CN236639",
#           "MONDO:0005252",
#           "UMLS:C1961112",
#           "MESH:D006333",
#           "SNOMEDCT:84114007",
#           "NCIT:C50577"
#         ],
#         "name": "heart failure"
#       },
#       {
#         "id": "MONDO:0024355",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "SNOMEDCT:54150009",
#           "UMLS:C0863094",
#           "MONDO:0024355",
#           "UMLS:C0035243",
#           "UMLS:C0041912",
#           "UMLS:C4759838",
#           "MEDDRA:10024970",
#           "MEDDRA:10062352",
#           "UMLS:C3544325",
#           "MESH:D012141",
#           "SNOMEDCT:275498002",
#           "MEDDRA:10046306",
#           "HP:0011947"
#         ],
#         "name": "respiratory tract infectious disease"
#       },
#       {
#         "id": "MONDO:0001673",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [
#           "diarrhea",
#           "diarrheal disease",
#           "diarrheal disorder",
#           "diarrhoea",
#           "frequent stools",
#           "loose stools",
#           "diarrhea of presumed infectious origin"
#         ],
#         "equivalent_identifiers": [
#           "MESH:D003967",
#           "DOID:13250",
#           "UMLS:C1290807",
#           "NCIT:C2987",
#           "UMLS:C0011991",
#           "SNOMEDCT:267060006",
#           "HP:0002014",
#           "SNOMEDCT:62315008",
#           "MONDO:0001673",
#           "SNOMEDCT:128333008"
#         ],
#         "name": "diarrheal disease"
#       },
#       {
#         "id": "MONDO:0001243",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "NCIT:C2992",
#           "MONDO:0001243",
#           "MESH:D004211",
#           "SNOMEDCT:67406007",
#           "DOID:11247",
#           "UMLS:C0860217",
#           "MEDDRA:10013442",
#           "NCIT:C131658",
#           "UMLS:C1868936",
#           "HP:0005521",
#           "UMLS:C4321305",
#           "UMLS:C0012739"
#         ],
#         "name": "disseminated intravascular coagulation"
#       },
#       {
#         "id": "MONDO:0021146",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [
#           "headache disorder",
#           "cephalgia syndrome",
#           "cephalgia syndromes",
#           "chronic daily headache",
#           "chronic daily headaches",
#           "chronic headache",
#           "chronic headaches",
#           "daily headache, chronic",
#           "daily headaches, chronic",
#           "headache syndrome",
#           "headache syndromes",
#           "headache, chronic",
#           "headache, chronic daily",
#           "headache, intractable",
#           "headaches, chronic",
#           "headaches, chronic daily",
#           "headaches, intractable",
#           "intractable headache",
#           "intractable headaches",
#           "syndrome, headache"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C0744648",
#           "SNOMEDCT:230461009",
#           "UMLS:C0948396",
#           "UMLS:C1328569",
#           "NCIT:C34661",
#           "SNOMEDCT:162308004",
#           "SNOMEDCT:162299003",
#           "SNOMEDCT:712831003",
#           "HP:0002315",
#           "UMLS:C0751190",
#           "UMLS:C0239888",
#           "UMLS:C0876980",
#           "UMLS:C4285864",
#           "EFO:0009550",
#           "UMLS:C1168188",
#           "UMLS:C0393735",
#           "UMLS:C0239886",
#           "MESH:D020773",
#           "UMLS:C0858898",
#           "MESH:D006261",
#           "SNOMEDCT:712826000",
#           "UMLS:C0751187",
#           "UMLS:C0857361",
#           "UMLS:C0423622",
#           "UMLS:C0423623",
#           "UMLS:C0474366",
#           "UMLS:C0857492",
#           "SNOMEDCT:162304002",
#           "UMLS:C0751192",
#           "UMLS:C0423621",
#           "UMLS:C0239885",
#           "MONDO:0021146",
#           "UMLS:C0018681",
#           "MEDDRA:10019211",
#           "SNOMEDCT:267096005",
#           "MEDDRA:10019231",
#           "MEDDRA:10060854",
#           "SNOMEDCT:445511002",
#           "UMLS:C0151293",
#           "UMLS:C0751189",
#           "UMLS:C0752149",
#           "UMLS:C1868934",
#           "SNOMEDCT:41413006",
#           "UMLS:C0856864",
#           "UMLS:C0751186",
#           "SNOMEDCT:86925001",
#           "SNOMEDCT:25064002",
#           "SNOMEDCT:162301005",
#           "UMLS:C0231613",
#           "UMLS:C0857471",
#           "UMLS:C0877781",
#           "SNOMEDCT:330007",
#           "UMLS:C1262010",
#           "UMLS:C0423618",
#           "UMLS:C0028838",
#           "SNOMEDCT:458241000124102",
#           "UMLS:C0858248",
#           "UMLS:C0752147"
#         ],
#         "name": "headache disorder"
#       },
#       {
#         "id": "MONDO:0005265",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "UMLS:C0021390",
#           "MONDO:0005265",
#           "SNOMEDCT:302168000",
#           "MESH:D015212",
#           "NCIT:C3138",
#           "SNOMEDCT:24526004",
#           "HP:0002037",
#           "UMLS:C0578878",
#           "DOID:0050589",
#           "MEDDRA:10021972",
#           "EFO:0003767"
#         ],
#         "name": "inflammatory bowel disease"
#       },
#       {
#         "id": "MONDO:0004995",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "UMLS:C0859057",
#           "MONDO:0004995",
#           "MEDDRA:10007649",
#           "DOID:1287",
#           "UMLS:C0728936",
#           "SNOMEDCT:49601007",
#           "UMLS:C0007222",
#           "NCIT:C2931",
#           "MESH:D002318",
#           "UMLS:C0243050",
#           "HP:0001626",
#           "UMLS:C0549406",
#           "UMLS:C0859056",
#           "MESH:D018376"
#         ],
#         "name": "cardiovascular disease"
#       },
#       {
#         "id": "MONDO:0019810",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "MONDO:0019810",
#           "SNOMEDCT:768962006",
#           "ORPHANET:95455",
#           "UMLS:C0014518",
#           "UMLS:C0858685",
#           "EFO:0004775",
#           "NCIT:C79777",
#           "SNOMEDCT:23067006",
#           "MEDDRA:10044223",
#           "UMLS:C0151626",
#           "MESH:D004816"
#         ],
#         "name": "toxic epidermal necrolysis"
#       },
#       {
#         "id": "MONDO:0005113",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "UMLS:C0858746",
#           "DOID:104",
#           "UMLS:C1096600",
#           "UMLS:C1096747",
#           "SNOMEDCT:87628006",
#           "UMLS:C0085423",
#           "MESH:D001424",
#           "EFO:0000771",
#           "UMLS:C1096601",
#           "NCIT:C2890",
#           "MEDDRA:10060945",
#           "UMLS:C0004623",
#           "MONDO:0005113"
#         ],
#         "name": "bacterial infectious disease"
#       },
#       {
#         "id": "MONDO:0005263",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "UMLS:C0856923",
#           "MONDO:0005263",
#           "UMLS:C0041696",
#           "MEDDRA:10012378",
#           "UMLS:C0541868",
#           "UMLS:C0541869",
#           "UMLS:C0154437",
#           "UMLS:C1386135",
#           "SNOMEDCT:192080009",
#           "HP:0000716",
#           "MEDDRA:10012401",
#           "NCIT:C35094",
#           "UMLS:C0581391",
#           "UMLS:C0859997",
#           "SNOMEDCT:712823008",
#           "UMLS:C0011581",
#           "UMLS:C0011570",
#           "UMLS:C1868899",
#           "SNOMEDCT:21061000119107",
#           "UMLS:C0349218",
#           "UMLS:C0235876"
#         ],
#         "psychiatric_disorder": true,
#         "name": "unipolar depression"
#       },
#       {
#         "id": "MONDO:0006932",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "DOID:11396",
#           "UMLS:C0034063",
#           "NCIT:C26868",
#           "EFO:1001134",
#           "UMLS:C1736185",
#           "MEDDRA:10037424",
#           "MONDO:0006932",
#           "UMLS:C0856142",
#           "UMLS:C0748123",
#           "HP:0100598",
#           "MESH:D011654",
#           "UMLS:C2939069",
#           "MEDDRA:10037423",
#           "SNOMEDCT:19242006"
#         ],
#         "acute_disease": true,
#         "name": "pulmonary edema"
#       },
#       {
#         "id": "MONDO:0015137",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "SNOMEDCT:386661006",
#           "SNOMEDCT:50177009",
#           "UMLS:C0860192",
#           "UMLS:C0015967",
#           "UMLS:C1709787",
#           "SNOMEDCT:704425001",
#           "ORPHANET:101995",
#           "MESH:D005334",
#           "UMLS:C0743842",
#           "NCIT:C35292",
#           "UMLS:C0743971",
#           "UMLS:C2830450",
#           "UMLS:C0856281",
#           "MESH:D005335",
#           "SNOMEDCT:102496004",
#           "UMLS:C0858754",
#           "NCIT:C118240",
#           "HP:0011134",
#           "NCIT:C34608",
#           "MONDO:0015137",
#           "UMLS:C4324354",
#           "SNOMEDCT:7520000",
#           "SNOMEDCT:274640006",
#           "MEDDRA:10037660",
#           "UMLS:C3889979",
#           "NCIT:C50720",
#           "UMLS:C1096446",
#           "MEDDRA:10034533",
#           "HP:0001945",
#           "UMLS:C0235723",
#           "UMLS:C0424781",
#           "UMLS:C0015974",
#           "NCIT:C26921",
#           "UMLS:C0015970",
#           "UMLS:C0239574",
#           "NCIT:C3038",
#           "UMLS:C1397229",
#           "SNOMEDCT:304213008",
#           "UMLS:C1699202",
#           "UMLS:C1504566",
#           "UMLS:C0085594"
#         ],
#         "syndromic_disease": true,
#         "name": "periodic fever syndrome"
#       },
#       {
#         "id": "MONDO:0021113",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "NCIT:C50594",
#           "MEDDRA:10038678",
#           "UMLS:C0858971",
#           "SNOMEDCT:31515003",
#           "SNOMEDCT:80954004",
#           "MESH:D007040",
#           "HP:0002093",
#           "SNOMEDCT:15993004",
#           "UMLS:C4020855",
#           "MEDDRA:10038695",
#           "MEDDRA:10009126",
#           "MESH:D012131",
#           "HP:0002791",
#           "NCIT:C116314",
#           "SNOMEDCT:409623005",
#           "UMLS:C4087530",
#           "UMLS:C1145670",
#           "EFO:0009686",
#           "UMLS:C3203358",
#           "MONDO:0021113",
#           "UMLS:C0264492",
#           "UMLS:C0398353",
#           "UMLS:C0948755",
#           "SNOMEDCT:709109004",
#           "MEDDRA:10021133",
#           "UMLS:C3805211",
#           "SNOMEDCT:409622000",
#           "HP:0002878",
#           "UMLS:C0035229",
#           "UMLS:C4324356",
#           "UMLS:C2363912",
#           "NCIT:C26872",
#           "UMLS:C0235063",
#           "DOID:11162",
#           "SNOMEDCT:39871006"
#         ],
#         "name": "respiratory failure"
#       },
#       {
#         "id": "MONDO:0004730",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [
#           "speech impediment or impairment"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C0751513",
#           "SNOMEDCT:62415009",
#           "SNOMEDCT:229751001",
#           "SNOMEDCT:69577009",
#           "HP:0000750",
#           "UMLS:C0233728",
#           "MEDDRA:10013931",
#           "HP:0002167",
#           "SNOMEDCT:29164008",
#           "UMLS:C4280574",
#           "UMLS:C0009090",
#           "UMLS:C0042940",
#           "MESH:D013064",
#           "SNOMEDCT:50219008",
#           "UMLS:C0542257",
#           "UMLS:C1527344",
#           "UMLS:C0019825",
#           "MEDDRA:10024796",
#           "UMLS:C0858568",
#           "UMLS:C3248383",
#           "UMLS:C1854348",
#           "UMLS:C3495145",
#           "UMLS:C0454644",
#           "HP:0001609",
#           "HP:0001618",
#           "MESH:D006685",
#           "UMLS:C0857508",
#           "MEDDRA:10013952",
#           "SNOMEDCT:47004009",
#           "UMLS:C0860619",
#           "HP:0002465",
#           "UMLS:C0233726",
#           "UMLS:C0751514",
#           "NCIT:C86950",
#           "SNOMEDCT:63416000",
#           "UMLS:C0860617",
#           "UMLS:C0454655",
#           "SNOMEDCT:449191001",
#           "SNOMEDCT:37732008",
#           "UMLS:C0860618",
#           "UMLS:C1527347",
#           "UMLS:C0855216",
#           "MESH:D007805",
#           "UMLS:C0541975",
#           "MONDO:0004730",
#           "UMLS:C4728001",
#           "UMLS:C3854685",
#           "UMLS:C0023014",
#           "UMLS:C0751201",
#           "SNOMEDCT:16617009",
#           "UMLS:C0854299",
#           "NCIT:C5041",
#           "UMLS:C0858567",
#           "DOID:92",
#           "UMLS:C0860616",
#           "UMLS:C0751512",
#           "UMLS:C3854612",
#           "UMLS:C0856983",
#           "UMLS:C1168248",
#           "UMLS:C1848207",
#           "UMLS:C0233715",
#           "MEDDRA:10041466",
#           "UMLS:C0037822",
#           "NCIT:C47813",
#           "SNOMEDCT:229721007",
#           "SNOMEDCT:162294008",
#           "UMLS:C0241210",
#           "UMLS:C0859023",
#           "UMLS:C0023012"
#         ],
#         "psychiatric_disorder": true,
#         "name": "speech disorder"
#       },
#       {
#         "id": "MONDO:0004900",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "synonyms": [],
#         "equivalent_identifiers": [
#           "NCIT:C118255",
#           "DOID:9847",
#           "UMLS:C0476207",
#           "UMLS:C0522359",
#           "MESH:D014717",
#           "SNOMEDCT:399153001",
#           "UMLS:C0220870",
#           "UMLS:C0857226",
#           "UMLS:C0042571",
#           "UMLS:C0012833",
#           "SNOMEDCT:248223005",
#           "UMLS:C0857314",
#           "SNOMEDCT:386705008",
#           "UMLS:C0522351",
#           "MEDDRA:10047340",
#           "UMLS:C0857087",
#           "MONDO:0004900",
#           "SNOMEDCT:103284002",
#           "SNOMEDCT:63024004",
#           "UMLS:C0155501",
#           "UMLS:C0853898",
#           "UMLS:C0581879",
#           "UMLS:C0234757",
#           "SNOMEDCT:50438001",
#           "SNOMEDCT:50041000",
#           "SNOMEDCT:315018008",
#           "HP:0002321",
#           "NCIT:C38057",
#           "HP:0010532",
#           "UMLS:C3854599",
#           "UMLS:C0852858",
#           "UMLS:C0413281",
#           "SNOMEDCT:399090003",
#           "UMLS:C0149746",
#           "UMLS:C0549239",
#           "MESH:D004244",
#           "SNOMEDCT:51568001",
#           "UMLS:C0234750",
#           "UMLS:C0271487",
#           "SNOMEDCT:162271007",
#           "SNOMEDCT:103292006",
#           "SNOMEDCT:103290003",
#           "UMLS:C0522357",
#           "UMLS:C0751573",
#           "UMLS:C0522349",
#           "UMLS:C0857011",
#           "MEDDRA:10013573",
#           "SNOMEDCT:404640003",
#           "UMLS:C1739421",
#           "SNOMEDCT:103282003",
#           "NCIT:C37943",
#           "SNOMEDCT:271789005",
#           "SNOMEDCT:87118001"
#         ],
#         "name": "peripheral vertigo"
#       }
#     ],
#     "edges": [
#       {
#         "id": "f7ba96a2d5c606323e97d07af7eaa18b",
#         "source_id": "MONDO:0100096",
#         "target_id": "NCBITaxon:2697049",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.79813
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 2972.641941068292,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "aff80436570aaf17f95b5acf1c5c0f7b",
#         "source_id": "CHEBI:4975",
#         "target_id": "NCBITaxon:2697049",
#         "type": "in_clinical_trial_for",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "source_database": "drugbank",
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "count": 1,
#         "rectified": true,
#         "relation_label": "in_clinical_trial_for",
#         "relation": "in_clinical_trial_for"
#       },
#       {
#         "id": "2280d6cddf5f10a8fd58de70f404b987",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0056821",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.7023969
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 0.43356351282442374,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "14174cce99ff32ab8c288ae1ef54257f",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0056821",
#         "type": "causes_adverse_event",
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 1.9620799999999998,
#         "ctime": [
#           1595082617.1515436
#         ],
#         "case_count": 20,
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "publications": [],
#         "ror": 1.9622099999999998,
#         "relation": [
#           "Aeolus:0000001"
#         ]
#       },
#       {
#         "id": "be11439ec57dcefc9f15abe6d1e762b9",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0019737",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.7003188
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 0.2317097301209472,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "812246ae2940eeefbd72ab73666c01fe",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0019737",
#         "type": "causes_adverse_event",
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 1.7465700000000002,
#         "ctime": [
#           1595082617.1429114
#         ],
#         "case_count": 39,
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "publications": [],
#         "ror": 1.7467599999999999,
#         "relation": [
#           "Aeolus:0000001"
#         ]
#       },
#       {
#         "id": "653fde0eee33086441d5077a731d974b",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0015796",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.7007806
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 2.4819251004707166,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "c303bbb38a2ec460a39ed06817d03073",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0015796",
#         "type": "causes_adverse_event",
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 3.40205,
#         "ctime": [
#           1595082617.1714506
#         ],
#         "case_count": 7,
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "publications": [],
#         "ror": 3.40217,
#         "relation": [
#           "Aeolus:0000001"
#         ]
#       },
#       {
#         "id": "7c7423ae1957fd581b156b0421d23294",
#         "source_id": "MONDO:0100096",
#         "target_id": "NCBIGene:7124",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.5879529
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 0.28975843838407,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "60c62cc42ccdd831a8a428633584aa73",
#         "source_id": "CHEBI:4975",
#         "target_id": "NCBIGene:7124",
#         "type": "increases_secretion_of",
#         "description": "increases secretion of",
#         "predicate_id": "biolink:increases_secretion_of",
#         "source_database": [
#           "ctd",
#           "ctd"
#         ],
#         "edge_source": [
#           "ctd.gene_to_drug_expanded",
#           "ctd.drug_to_gene_expanded"
#         ],
#         "ctime": [
#           1585074891.331755,
#           1593820253.5950353
#         ],
#         "publications": [
#           "PMID:17698507"
#         ],
#         "relation_label": [
#           "increases secretion of",
#           "increases secretion of"
#         ],
#         "taxon": "taxon:ncbitaxon:10116",
#         "relation": [
#           "CTD:increases_secretion_of",
#           "CTD:increases_secretion_of"
#         ]
#       },
#       {
#         "id": "eb2b32c3a22ebcefac4d52819d41db51",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0005478",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.586854
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 0.2899790346415031,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "7325ed3030aa9e947dd4064104317cfc",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005478",
#         "type": "contributes_to",
#         "predicate_id": "biolink:contributes_to",
#         "source_database": [
#           "ctd"
#         ],
#         "edge_source": [
#           "ctd.disease_to_chemical"
#         ],
#         "ctime": [
#           1585042796.1710408
#         ],
#         "publications": [
#           "PMID:19358226"
#         ],
#         "relation_label": [
#           "marker_mechanism"
#         ],
#         "relation": [
#           "CTD:marker_mechanism"
#         ]
#       },
#       {
#         "id": "cc99bb33ef8f58c50731d908ae6e750d",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005478",
#         "type": "causes_adverse_event",
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 2.45513,
#         "ctime": [
#           1595082617.1368022
#         ],
#         "case_count": 86,
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "publications": [],
#         "ror": 2.4559599999999997,
#         "relation": [
#           "Aeolus:0000001"
#         ]
#       },
#       {
#         "id": "109061a2db0cad5009e55fc1cab09575",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0004652",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.466953
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 0.5380427775446814,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "ec2db97f8fc49b086acffa6f4f22dbc8",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0004652",
#         "type": "causes_adverse_event",
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 3.56028,
#         "ctime": [
#           1595082617.1368558
#         ],
#         "case_count": 86,
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "publications": [],
#         "ror": 3.5617400000000004,
#         "relation": [
#           "Aeolus:0000001"
#         ]
#       },
#       {
#         "id": "c952240b0e55a98a7d4eb53656b348f1",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0002258",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.468371
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 8.500365898189639,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "4cf89334ad046b12f517e13367c341bd",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0002258",
#         "type": "prevents",
#         "predicate_id": "biolink:prevents",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 0.69686,
#         "ctime": [
#           1595082617.1346278
#         ],
#         "case_count": 129,
#         "relation_label": [
#           "prevents"
#         ],
#         "publications": [],
#         "ror": 0.6966,
#         "relation": [
#           "RO:0002599"
#         ]
#       },
#       {
#         "id": "a9c76d8e36531364d25cb3f83572c806",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0001208",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.4688883
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 2.1990756687937174,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "3784d2f2916dc24cfda753828b01269d",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0001208",
#         "type": "causes_adverse_event",
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 1.72403,
#         "ctime": [
#           1595082617.1350465
#         ],
#         "case_count": 121,
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "publications": [],
#         "ror": 1.7246099999999998,
#         "relation": [
#           "Aeolus:0000001"
#         ]
#       },
#       {
#         "id": "5036689d55b8f9f9e8d2c35fdfb3e258",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0045057",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.4670088
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 2.3080327136180716,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "9f4df0444db2a3ffc09c25e8b0713578",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0045057",
#         "type": "has_phenotype",
#         "predicate_id": "RO:0002200",
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "ctime": [
#           1597669781.6380565
#         ],
#         "publications": [],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "notes": "Covid symptom tracker",
#         "relation": [
#           "RO:0002200"
#         ]
#       },
#       {
#         "id": "908ca5052b017f4ea79f769b5c3a5897",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0045057",
#         "type": "contributes_to",
#         "predicate_id": "biolink:contributes_to",
#         "source_database": [
#           "ctd"
#         ],
#         "edge_source": [
#           "ctd.disease_to_chemical"
#         ],
#         "ctime": [
#           1585042672.8032074
#         ],
#         "publications": [
#           "PMID:3243179",
#           "PMID:9545163"
#         ],
#         "relation_label": [
#           "marker_mechanism"
#         ],
#         "relation": [
#           "CTD:marker_mechanism"
#         ]
#       },
#       {
#         "id": "1e4dfcec8da6409799fb897f6e02a746",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0045057",
#         "type": "causes_adverse_event",
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 2.34115,
#         "ctime": [
#           1595082617.1313725
#         ],
#         "case_count": 366,
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "publications": [],
#         "ror": 2.34441,
#         "relation": [
#           "Aeolus:0000001"
#         ]
#       },
#       {
#         "id": "8183f213914fbca4a1ada57f34367e93",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0045057",
#         "type": "prevents",
#         "predicate_id": "biolink:prevents",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 0.76758,
#         "ctime": [
#           1595082617.1311233
#         ],
#         "case_count": 424,
#         "relation_label": [
#           "prevents"
#         ],
#         "publications": [],
#         "ror": 0.7669199999999999,
#         "relation": [
#           "RO:0002599"
#         ]
#       },
#       {
#         "id": "c7ce253a2de06705ce6c6c9e2155ab4a",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0005249",
#         "type": "related_to",
#         "enrichment_p": 0.0,
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.3126245
#         ],
#         "publications": [],
#         "relation_label": [
#           "related_to"
#         ],
#         "num_publications": 47.804438938838985,
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ]
#       },
#       {
#         "id": "da825870d445b043d8c03cde137e1499",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005249",
#         "type": "causes_adverse_event",
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "prr": 1.35095,
#         "ctime": [
#           1595082617.1365345
#         ],
#         "case_count": 90,
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "publications": [],
#         "ror": 1.3511600000000001,
#         "relation": [
#           "Aeolus:0000001"
#         ]
#       },
#       {
#         "id": "d1b2d3715085b8d8fade58301abb1dc2",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0003785",
#         "type": "related_to",
# ...
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "2280d6cddf5f10a8fd58de70f404b987"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "14174cce99ff32ab8c288ae1ef54257f"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0019737"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "be11439ec57dcefc9f15abe6d1e762b9"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "812246ae2940eeefbd72ab73666c01fe"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0015796"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "653fde0eee33086441d5077a731d974b"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "c303bbb38a2ec460a39ed06817d03073"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "NCBIGene:7124"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "7c7423ae1957fd581b156b0421d23294"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "60c62cc42ccdd831a8a428633584aa73"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005478"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "eb2b32c3a22ebcefac4d52819d41db51"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "7325ed3030aa9e947dd4064104317cfc"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "cc99bb33ef8f58c50731d908ae6e750d"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0004652"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "109061a2db0cad5009e55fc1cab09575"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "ec2db97f8fc49b086acffa6f4f22dbc8"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0002258"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "c952240b0e55a98a7d4eb53656b348f1"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "4cf89334ad046b12f517e13367c341bd"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0001208"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "a9c76d8e36531364d25cb3f83572c806"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "3784d2f2916dc24cfda753828b01269d"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0045057"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "5036689d55b8f9f9e8d2c35fdfb3e258"
#         },
#         {
#           "qg_id": "ab",
#           "kg_id": "9f4df0444db2a3ffc09c25e8b0713578"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "908ca5052b017f4ea79f769b5c3a5897"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "1e4dfcec8da6409799fb897f6e02a746"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "8183f213914fbca4a1ada57f34367e93"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005249"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "c7ce253a2de06705ce6c6c9e2155ab4a"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "da825870d445b043d8c03cde137e1499"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0003785"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "d1b2d3715085b8d8fade58301abb1dc2"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "1173aa8a4bf2e0a4d42adcad4fbec00a"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005252"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "dbf99209970155864e61a71189d26623"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "8a06a374968eb4b52fc312e9bc10a0b9"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0024355"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "c6ad4bcfc2f9404760353d0c6e14a757"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "1846fe0ab4733cbf57cf1e1c450a555a"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0001673"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "e17690f475384c9eb9cff97ea02656db"
#         },
#         {
#           "qg_id": "ab",
#           "kg_id": "449bd7a67b7c8dcec04ed68e60170c65"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "c1ceb82427292fa60cd18f538af273b1"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0001243"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "94c0e06a30513062fcee89e3ca7363bb"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "5230997850fea7af82071c758253bfd6"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0021146"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "02a3b9d04dc8f00baad56f1d3c2eb0ae"
#         },
#         {
#           "qg_id": "ab",
#           "kg_id": "39bf57a77e9522c8643e2a4bdb6ccd8f"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "1b344638fcb4da3c3c3f84e0fa30fb0b"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "ca8fa0f8260433fef4eac6579ef883fc"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005265"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "7f29d713370c8aacab232c743ee3987a"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "d573cb39419143de1dc2d84a0206eb30"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0004995"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "cee8f061f83713bca61cc0f7ca083f4e"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "84aa4a49db52be6a1be71060f32b219c"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0019810"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "0c55c26d87be113f70e4dda7cbd75d85"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "360a39b818b2e4df83794bc95e083724"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005113"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "bbaaff34c1aa38d09cbb1ea3b971c359"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "6d7efc3a7025d38ea53fc918545ff336"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005263"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "9cafac13235b8ae745a7930a4c9436cf"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "68727deb8a51a89077d0dbf040f34025"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0006932"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "c26987f51ee73278e67a0c91d835d0af"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "9d61bda4fbdcc44ba2cb202c801a1e2d"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0015137"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "2c23784201bbecd03ac2d95c7670b817"
#         },
#         {
#           "qg_id": "ab",
#           "kg_id": "4b5cc0ba33025b8d27e1ea9c61d24545"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "2df290232bf3d30a27ad874836d05262"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0021113"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "6b637092c75966e1c35ee55ef62219fc"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "a72584a4e86423d6d94314f0bce9ddc5"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "7eebea1a304464128ccfe1e404249f63"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "c0daa6d354f8f344dff3c0dccf6863ed"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0004730"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "04b388385c74f1f389d8edc8a2b76707"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "52a00428d863733171ef71ec9f0de00b"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "c9605cdaf3cf404cd43bb7b2f70167f5"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0004900"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "a0ab13c777e2d23b0ea6f82a2d06dd88"
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "97ba863e0634a258a7bd4f13f5c2154b"
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null
#     }
#   ]
# }

# %%
with open('famcov.json','w') as outf:
    json.dump(robokop_result,outf,indent=2)

# %% [markdown]
# ## Coalesce Answers by Property

# %%
url = 'https://answercoalesce.renci.org/coalesce'
params = {'method':'property'}
p_r = requests.post(url,json=robokop_result,params=params)
print(p_r.status_code)
property_result = p_r.json()
# Out:
# 200

# %%
property_result['results']
# Out:
# []

# %%
results = property_result['results']
num_grouped=[]
p_values=[]
properties=[]
for result in results:
    chemnode = result['node_bindings'][2]
    for p,prop in zip(chemnode['p_values'],chemnode['properties']):
        num_grouped.append(len(chemnode['kg_id']))
        p_values.append(p)
        properties.append(prop)
df = pd.DataFrame( {'NumberGrouped': num_grouped, 'p_value':p_values, 'PropertyGroup':properties})
df.sort_values(by='p_value',inplace=True)
df
# Out:
# Empty DataFrame
# Columns: [NumberGrouped, p_value, PropertyGroup]
# Index: []

# %% [markdown]
# ## Coalesce Answers by Ontology

# %%
url = 'https://answercoalesce.renci.org/coalesce'
params = {'method':'ontology'}
o_r = requests.post(url,json=robokop_result,params=params)
print(o_r.status_code)
ontology_result = o_r.json()
print( len(ontology_result['results']))
# Out:
# 200
# 3

# %%
results = ontology_result['results']
for result in results:
    print('\n================')
    chemnode = result['node_bindings'][1]
    sclass = chemnode['superclass']
    label = getlabel(sclass)
    nodes = chemnode['kg_id']
    labels = {x: f'{getlabel(x)}' for x in nodes }
    for x in nodes:
        print(f'{labels[x]} ({x})')
    print('----have superclass----')
    print(f'{label} ({sclass})')
# Out:
# ================
# acute respiratory distress syndrome (MONDO:0006502)
# respiratory failure (MONDO:0021113)
# ----have superclass----
# respiratory failure (MONDO:0021113)
#
# ================
# cortisol (CHEBI:17650)
# prednisone (CHEBI:8382)
# dexamethasone (CHEBI:41879)
# methylprednisolone succinate (CHEBI:135765)
# ----have superclass----
# corticosteroid hormone (CHEBI:36699)
#
# ================
# prednisone (CHEBI:8382)
# dexamethasone (CHEBI:41879)
# cortisol (CHEBI:17650)
# ----have superclass----
# glucocorticoid (CHEBI:24261)

# %%
from copy import deepcopy
onrd = deepcopy(ontology_result)
for n in onrd['query_graph']['nodes']:
    if 'curie' in n and n['curie'] is None:
        del[n['curie']]
for n in onrd['knowledge_graph']['nodes']:
    if 'name' not in n:
        label = getlabel(n['id'])
        n['name'] = label
for e in onrd['knowledge_graph']['edges']:
    e['id'] = str(e['id'])
for r in onrd['results']:
    for eb in r['edge_bindings']:
        eb['kg_id'] = [ str(x) for x in eb['kg_id']]
react_component = GammaViewer(props={"data":onrd})
display(react_component)

# %%
with open('ontology_output.json.txt','w') as outf:
    json.dump(onrd,outf,indent=2)

# %% [markdown]
# ## Coalescence by Graph

# %% [markdown]
# Coalescence by graph is similar to coalescence by ontology, but the new relationships can be more general than `is_a`.

# %%
url = 'https://answercoalesce.renci.org/coalesce'
params = {'method':'graph'}
g_r = requests.post(url,json=robokop_result,params=params)
print(g_r.status_code)
graph_result = g_r.json()
print( len(graph_result['results']))
# Out:
# 200
# 25

# %%
from copy import deepcopy
gd = deepcopy(graph_result)
for n in gd['query_graph']['nodes']:
    if 'curie' in n and n['curie'] is None:
        del[n['curie']]
for n in gd['knowledge_graph']['nodes']:
    if 'name' not in n:
        label = getlabel(n['id'])
        n['name'] = label
for e in gd['knowledge_graph']['edges']:
    e['id'] = str(e['id'])
for r in gd['results']:
    for eb in r['edge_bindings']:
        eb['kg_id'] = [ str(x) for x in eb['kg_id']]
react_component = GammaViewer(props={"data":gd})
display(react_component)

# %%
def draw_one(results,rnum):
    g = deepcopy(results)
    g['results']=[g['results'][rnum]]
    kgs = set()
    for nb in g['results'][0]['node_bindings']:
        for kgid in nb['kg_id']:
            kgs.add(kgid)
    kg = g['knowledge_graph']
    kg['nodes'] = [n for n in kg['nodes'] if n['id'] in kgs ]
    kg['edges'] = [e for e in kg['edges'] if (e['source_id'] in kgs) and (e['target_id'] in kgs)]
    react_component = GammaViewer(props={"data":g})
    display(react_component)

# %%
draw_one(gd,3)

# %%
gd
# Out:
# {'query_graph': {'edges': [{'id': 'ab', 'source_id': 'a', 'target_id': 'b'},
#    {'id': 'bc', 'source_id': 'c', 'target_id': 'b'},
#    {'id': 'extra_qe_0', 'source_id': 'b', 'target_id': 'extra_qn_0'}],
#   'nodes': [{'curie': ['MONDO:0100096'], 'id': 'a', 'type': 'disease'},
#    {'id': 'b', 'type': 'named_thing', 'set': True},
#    {'curie': ['CHEBI:4975'], 'id': 'c', 'type': 'chemical_substance'},
#    {'id': 'extra_qn_0', 'type': []}]},
#  'knowledge_graph': {'edges': [{'ctime': [1592973258.6295419],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 7.200162544618264e-26,
#     'id': '6495101038d3ebd2aef30675f0bef227',
#     'num_publications': 0.8943779167033549,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'CHEBI:29320',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 3,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': '4c4115b44968337424dd20dba4f70e0c',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:29320',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592883766.4699512, 1592988131.9177973],
#     'edge_source': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'enrichment_p': 1.3043294894440849e-36,
#     'id': 'd8680bb5602b6b89d26a25b24e2c095b',
#     'num_publications': 0.6291631201510571,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH', 'SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to', 'related_to'],
#     'source_database': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'source_id': 'CHEBI:91766',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 1,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': '421161f1bf8904ea7ee3e2133c21d58c',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:91766',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592978071.666772],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 5.472205453104307e-26,
#     'id': 'cb3ea2a62b1f66ce84418e8a3be0e8ef',
#     'num_publications': 0.9911346893252325,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'CHEBI:27140',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592978068.1861784],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 4.574130896612511e-21,
#     'id': '33c1128df44678aa7e2c4b00bef7ed80',
#     'num_publications': 11.816381233306911,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'CHEBI:27140',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592986981.0051198],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 2.133443398140935e-31,
#     'id': '3362f77d3da71d2a78c1fa2c2a377777',
#     'num_publications': 0.7182144149961355,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'CHEBI:41879',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 4,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': 'ea0ac9ce749f81122601bc5e874f74bc',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:41879',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592883732.5642235],
#     'edge_source': ['cord19_scibite_v5'],
#     'enrichment_p': 2.570516884443281e-05,
#     'id': 'ebf691afed5e5d1f15efb4c068868544',
#     'num_publications': 0.8929597565218225,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scibite_v5'],
#     'source_id': 'CHEBI:135765',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 1,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': '840140149eadac3be9345260d78fc8be',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:135765',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592884086.4851],
#     'edge_source': ['cord19_scibite_v5'],
#     'enrichment_p': 4.541758585377523e-05,
#     'id': '8af37d23e5428c5a1cb8547385f6772c',
#     'num_publications': 0.896040175025774,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scibite_v5'],
#     'source_id': 'MONDO:0005009',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592981172.099994],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.6989478782165154e-28,
#     'id': '97d2d4d898611e086700cdd83d8e97fd',
#     'num_publications': 0.8548858755735571,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0005009',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592883708.3244195, 1592997726.0604272],
#     'edge_source': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'enrichment_p': 1.1546909482235062e-21,
#     'id': '37894ba3dd3eb368addfaa8b2bdd3339',
#     'num_publications': 0.5792702493811942,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH', 'SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to', 'related_to'],
#     'source_database': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'source_id': 'CHEBI:2676',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 1,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': '38463c3f2f4fa6107f8ed8e342e9c4b0',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:2676',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592884106.6600294, 1592973733.1272883],
#     'edge_source': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'enrichment_p': 5.7223013649918366e-55,
#     'id': '6f1af85dfe9fca1dbd398d8eb7fd82ff',
#     'num_publications': 17.21551759560917,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH', 'SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to', 'related_to'],
#     'source_database': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'source_id': 'MONDO:0021113',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592973733.1271975],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.0042746400658484e-55,
#     'id': '21e0fb31f5500329d0e145e1a1c1d73e',
#     'num_publications': 17.2972977996928,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0021113',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592998728.6675196],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.8114549349702598e-21,
#     'id': 'c628d14b6df7def8adc0ef83e9b05bf1',
#     'num_publications': 1.8800446127204955,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0005478',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592998728.5039413],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 8.01600147293797e-22,
#     'id': 'eb2b32c3a22ebcefac4d52819d41db51',
#     'num_publications': 1.8947565378180857,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0005478',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592998728.5023954],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 0.0,
#     'id': '91d70bc5d586a986d737b57b60f58470',
#     'num_publications': 914.567306507,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592883297.4206164],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': 'fab6806d5b0df8e30151ea1996f1801b',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0045057',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.5563283],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '435e08ee81641e965b42ff260d8ff0a2',
#     'notes': 'https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0021146',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.4094603],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '68056e92b90c88ad659225911cff2241',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0001673',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.2349684],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': 'f9ae048208c0ca25ac0944ec49880d80',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'HP:0002098',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.232173],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '073a448000db4534afdc5852e8827c6b',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0015137',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.493145],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '7575a15c9db427fcff8a64e062782e7a',
#     'notes': 'https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0004900',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.4271076],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': 'a36a8e13acb3df3e2fbaa557a64b85c7',
#     'notes': 'https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'HP:0003326',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.424095],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': 'e58a3b85f45f7ad8fc9c9865a690d844',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'HP:0002094',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.4206164],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '9f4df0444db2a3ffc09c25e8b0713578',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0045057',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.5563283],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '39bf57a77e9522c8643e2a4bdb6ccd8f',
#     'notes': 'https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0021146',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.4094603],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '449bd7a67b7c8dcec04ed68e60170c65',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0001673',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.2349684],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '621c2897d9cd436ad9d0a0a5d1b7fd44',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'HP:0002098',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.232173],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '4b5cc0ba33025b8d27e1ea9c61d24545',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0015137',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.493145],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': 'a0ab13c777e2d23b0ea6f82a2d06dd88',
#     'notes': 'https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'MONDO:0004900',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.4271076],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': 'd28135ab3f9c8ecb3bad81929bd68357',
#     'notes': 'https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'HP:0003326',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592883297.424095],
#     'edge_source': ['covid_phenotypes_csv'],
#     'id': '3faaa74ce473aca1932f5d91ff7238db',
#     'notes': 'Covid symptom tracker',
#     'predicate_id': 'RO:0002200',
#     'publications': [],
#     'relation': ['RO:0002200'],
#     'relation_label': ['has_phenotype'],
#     'source_database': ['covid_phenotypes_csv'],
#     'source_id': 'MONDO:0100096',
#     'target_id': 'HP:0002094',
#     'type': 'has_phenotype',
#     'weight': 1},
#    {'ctime': [1592982376.5923533],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 4.4987601399449174e-38,
#     'id': '30fbd2d5b20760ca28f0a501143f2212',
#     'num_publications': 1.3086363769774882,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0001673',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1593000703.8206472],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 8.578597271860192e-28,
#     'id': '11a0002c5b1939093e85a34dd17eec0d',
#     'num_publications': 0.5279196384021602,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'CHEBI:16899',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 1,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': '8334c5cbc77f948b76c66df621baa667',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:16899',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1585042796.1710408],
#     'edge_source': ['ctd.disease_to_chemical'],
#     'id': '7325ed3030aa9e947dd4064104317cfc',
#     'predicate_id': 'RO:0002326',
#     'publications': ['PMID:19358226'],
#     'relation': ['CTD:marker_mechanism'],
#     'relation_label': ['marker_mechanism'],
#     'source_database': ['ctd'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0005478',
#     'type': 'contributes_to',
#     'weight': 1},
#    {'ctime': [1585042672.8032074],
#     'edge_source': ['ctd.disease_to_chemical'],
#     'id': '908ca5052b017f4ea79f769b5c3a5897',
#     'predicate_id': 'RO:0002326',
#     'publications': ['PMID:3243179', 'PMID:9545163'],
#     'relation': ['CTD:marker_mechanism'],
#     'relation_label': ['marker_mechanism'],
#     'source_database': ['ctd'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0045057',
#     'type': 'contributes_to',
#     'weight': 1},
#    {'ctime': [1585046178.4621778],
#     'edge_source': ['ctd.disease_to_chemical'],
#     'id': '1b344638fcb4da3c3c3f84e0fa30fb0b',
#     'predicate_id': 'RO:0002326',
#     'publications': ['PMID:2563629'],
#     'relation': ['CTD:marker_mechanism'],
#     'relation_label': ['marker_mechanism'],
#     'source_database': ['ctd'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0021146',
#     'type': 'contributes_to',
#     'weight': 1},
#    {'case_count': 7,
#     'ctime': [1587851144.023563],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '2fcb26c5435fda1b99c632c3e5e99efd',
#     'predicate_id': 'biolink:causes_adverse_event',
#     'prr': 3.6926400000000004,
#     'publications': [],
#     'relation': ['Aeolus:0000001'],
#     'relation_label': ['causes_or_contributes_to'],
#     'ror': 3.69276,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0005379',
#     'type': 'causes_adverse_event',
#     'weight': 1},
#    {'case_count': 86,
#     'ctime': [1587851143.9913058],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': 'cc99bb33ef8f58c50731d908ae6e750d',
#     'predicate_id': 'biolink:causes_adverse_event',
#     'prr': 2.45513,
#     'publications': [],
#     'relation': ['Aeolus:0000001'],
#     'relation_label': ['causes_or_contributes_to'],
#     'ror': 2.4559599999999997,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0005478',
#     'type': 'causes_adverse_event',
#     'weight': 1},
#    {'case_count': 90,
#     'ctime': [1587851143.9910216],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': 'da825870d445b043d8c03cde137e1499',
#     'predicate_id': 'biolink:causes_adverse_event',
#     'prr': 1.35095,
#     'publications': [],
#     'relation': ['Aeolus:0000001'],
#     'relation_label': ['causes_or_contributes_to'],
#     'ror': 1.3511600000000001,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0005249',
#     'type': 'causes_adverse_event',
#     'weight': 1},
#    {'case_count': 160,
#     'ctime': [1587851143.9883249],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '26681dad7296fe33215922a961392821',
#     'predicate_id': 'biolink:causes_adverse_event',
#     'prr': 2.0255099999999997,
#     'publications': [],
#     'relation': ['Aeolus:0000001'],
#     'relation_label': ['causes_or_contributes_to'],
#     'ror': 2.02659,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0006502',
#     'type': 'causes_adverse_event',
#     'weight': 1},
#    {'case_count': 214,
#     'ctime': [1587851143.9871805],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '1e4dfcec8da6409799fb897f6e02a746',
#     'predicate_id': 'biolink:causes_adverse_event',
#     'prr': 1.85444,
#     'publications': [],
#     'relation': ['Aeolus:0000001'],
#     'relation_label': ['causes_or_contributes_to'],
#     'ror': 1.85565,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0045057',
#     'type': 'causes_adverse_event',
#     'weight': 1},
#    {'case_count': 328,
#     'ctime': [1587851143.986168],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '8872e78619d787c6ebede9c092e74db5',
#     'predicate_id': 'biolink:causes_adverse_event',
#     'prr': 1.2686600000000001,
#     'publications': [],
#     'relation': ['Aeolus:0000001'],
#     'relation_label': ['causes_or_contributes_to'],
#     'ror': 1.26925,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0005009',
#     'type': 'causes_adverse_event',
#     'weight': 1},
#    {'case_count': 336,
#     'ctime': [1587851143.986006],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '5d1a7a8fad6fa52d4eec8857c540a664',
#     'predicate_id': 'biolink:causes_adverse_event',
#     'prr': 1.50962,
#     'publications': [],
#     'relation': ['Aeolus:0000001'],
#     'relation_label': ['causes_or_contributes_to'],
#     'ror': 1.51076,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0003019',
#     'type': 'causes_adverse_event',
#     'weight': 1},
#    {'case_count': 524,
#     'ctime': [1587851143.985148],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': 'a72584a4e86423d6d94314f0bce9ddc5',
#     'predicate_id': 'biolink:causes_adverse_event',
#     'prr': 1.59875,
#     'publications': [],
#     'relation': ['Aeolus:0000001'],
#     'relation_label': ['causes_or_contributes_to'],
#     'ror': 1.60084,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0021113',
#     'type': 'causes_adverse_event',
#     'weight': 1},
#    {'case_count': 1555,
#     'ctime': [1587851143.9842718],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '2df290232bf3d30a27ad874836d05262',
#     'predicate_id': 'biolink:causes_adverse_event',
#     'prr': 1.4644,
#     'publications': [],
#     'relation': ['Aeolus:0000001'],
#     'relation_label': ['causes_or_contributes_to'],
#     'ror': 1.4692399999999999,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0015137',
#     'type': 'causes_adverse_event',
#     'weight': 1},
#    {'case_count': 320,
#     'ctime': [1587872048.4022918],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '7439d7827535887b5a70c9c947bc6450',
#     'predicate_id': 'RO:0002599',
#     'prr': 0.70729,
#     'publications': [],
#     'relation': ['RO:0002599'],
#     'relation_label': ['prevents'],
#     'ror': 0.70667,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'HP:0003326',
#     'type': 'prevents',
#     'weight': 1},
#    {'case_count': 463,
#     'ctime': [1587872048.4015822],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '08fad98cd9189aca091f94ce1263db39',
#     'predicate_id': 'RO:0002599',
#     'prr': 0.7732100000000001,
#     'publications': [],
#     'relation': ['RO:0002599'],
#     'relation_label': ['prevents'],
#     'ror': 0.77251,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'HP:0012735',
#     'type': 'prevents',
#     'weight': 1},
#    {'case_count': 1293,
#     'ctime': [1587872048.3996162],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': 'b507d7530765741a28afd91562ad49d1',
#     'predicate_id': 'RO:0002599',
#     'prr': 0.83129,
#     'publications': [],
#     'relation': ['RO:0002599'],
#     'relation_label': ['prevents'],
#     'ror': 0.82983,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'HP:0002098',
#     'type': 'prevents',
#     'weight': 1},
#    {'case_count': 65,
#     'ctime': [1587851143.9932017],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '84aa4a49db52be6a1be71060f32b219c',
#     'predicate_id': 'RO:0002599',
#     'prr': 0.72951,
#     'publications': [],
#     'relation': ['RO:0002599'],
#     'relation_label': ['prevents'],
#     'ror': 0.72939,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0004995',
#     'type': 'prevents',
#     'weight': 1},
#    {'case_count': 424,
#     'ctime': [1587851143.985526],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '8183f213914fbca4a1ada57f34367e93',
#     'predicate_id': 'RO:0002599',
#     'prr': 0.76758,
#     'publications': [],
#     'relation': ['RO:0002599'],
#     'relation_label': ['prevents'],
#     'ror': 0.7669199999999999,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0045057',
#     'type': 'prevents',
#     'weight': 1},
#    {'case_count': 867,
#     'ctime': [1587851143.9844875],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': 'ca8fa0f8260433fef4eac6579ef883fc',
#     'predicate_id': 'RO:0002599',
#     'prr': 0.69191,
#     'publications': [],
#     'relation': ['RO:0002599'],
#     'relation_label': ['prevents'],
#     'ror': 0.69012,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0021146',
#     'type': 'prevents',
#     'weight': 1},
#    {'case_count': 758,
#     'ctime': [1587851143.9846506],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': 'a2178d4e628eefdc535e66edd7b15e52',
#     'predicate_id': 'RO:0002599',
#     'prr': 0.87187,
#     'publications': [],
#     'relation': ['RO:0002599'],
#     'relation_label': ['prevents'],
#     'ror': 0.8712200000000001,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0003699',
#     'type': 'prevents',
#     'weight': 1},
#    {'case_count': 936,
#     'ctime': [1587851143.984433],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '97ba863e0634a258a7bd4f13f5c2154b',
#     'predicate_id': 'RO:0002599',
#     'prr': 0.76794,
#     'publications': [],
#     'relation': ['RO:0002599'],
#     'relation_label': ['prevents'],
#     'ror': 0.76649,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0004900',
#     'type': 'prevents',
#     'weight': 1},
#    {'case_count': 941,
#     'ctime': [1587851143.9844065],
#     'edge_source': ['mychem.get_adverse_events'],
#     'id': '286175077d57b4f311c121f3a29639c3',
#     'predicate_id': 'RO:0002599',
#     'prr': 0.64252,
#     'publications': [],
#     'relation': ['RO:0002599'],
#     'relation_label': ['prevents'],
#     'ror': 0.64027,
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0005379',
#     'type': 'prevents',
#     'weight': 1},
#    {'ctime': [1587851226.157031],
#     'edge_source': ['mychem.get_drugcentral'],
#     'id': 'c1ceb82427292fa60cd18f538af273b1',
#     'predicate_id': 'biolink:contraindicated_for',
#     'publications': [],
#     'relation': ['DrugCentral:0000001'],
#     'relation_label': ['contraindication'],
#     'source_database': ['mychem'],
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0001673',
#     'type': 'contraindicated_for',
#     'weight': 1},
#    {'count': 1,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': 'c0daa6d354f8f344dff3c0dccf6863ed',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592884173.117955, 1592973447.070259],
#     'edge_source': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'enrichment_p': 1.3129856984321078e-65,
#     'id': '2a2c20ef3a15a0dce005d5e8b1e22a1d',
#     'num_publications': 18.41552053065658,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH', 'SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to', 'related_to'],
#     'source_database': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'source_id': 'MONDO:0006502',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592973447.070135],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 5.914513174427336e-67,
#     'id': 'a44804391705f164a5bb9c204716c92c',
#     'num_publications': 18.568955759052173,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0006502',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592884092.8484874, 1592971690.160379],
#     'edge_source': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'enrichment_p': 2.5e-323,
#     'id': 'a32a6ee9ea3aa7d354cd1a77678d0e02',
#     'num_publications': 70.26593290481644,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH', 'SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to', 'related_to'],
#     'source_database': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'source_id': 'MONDO:0005249',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592971690.1602328],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 4.3989725225014235e-273,
#     'id': '8386cced5413d3602a1e4332437c341f',
#     'num_publications': 64.24939904904464,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0005249',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592980832.8028204],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 2.9144536752952735e-201,
#     'id': 'e143a8681297e111bf172beccaa51605',
#     'num_publications': 27.60019664817587,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0005379',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592980832.802712],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 5.707133249646652e-201,
#     'id': 'ad98da8d0cdb2b95e6ca0a652f40569a',
#     'num_publications': 27.528861054856034,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0005379',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592987618.7928975],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 2.530428493674143e-29,
#     'id': 'c969c528d3617853bb34aa247ed9e95d',
#     'num_publications': 0.7145294629841605,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'CHEBI:15365',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 3,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': '37df1bf232ea833789b40a3153d8b555',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:15365',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592884091.5928812, 1592974541.6855977],
#     'edge_source': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'enrichment_p': 7.71969765216213e-115,
#     'id': '1c48c41821627f5d739c2c5a487cf59c',
#     'num_publications': 38.651882832907766,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH', 'SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to', 'related_to'],
#     'source_database': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'source_id': 'MONDO:0015137',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592974546.2627447],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 7.208700043189353e-21,
#     'id': '1959115ab28102902728ed814b1dc383',
#     'num_publications': 0.9974944478686665,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0015137',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592974541.685525],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.1321248092743078e-111,
#     'id': '4517e987116abb2e00576600b614b253',
#     'num_publications': 37.99496981792923,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0015137',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592983187.2642658],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.3664049376447833e-119,
#     'id': 'b8fd8b1f41940990aa64c864bbd11673',
#     'num_publications': 22.03710193419624,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0004995',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592983187.2641325],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.5827762324952198e-123,
#     'id': '3a2a0ef902c24176627a0fe0a4d8b08d',
#     'num_publications': 22.367153150773383,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0004995',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592972718.3064404],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 3.0054990336362203e-251,
#     'id': '20efb5427532feca8c4414eec5dc08a7',
#     'num_publications': 51.11950632502715,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'HP:0012735',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592972718.306351],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.6811270220702778e-246,
#     'id': '449ad2390a9c19c7160928c6a90c676e',
#     'num_publications': 50.49990901353058,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'HP:0012735',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592988285.4935071],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.445935151856876e-34,
#     'id': 'c625e04a5df86b5bb725f89028c741ff',
#     'num_publications': 0.7224756146478432,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'CHEBI:8382',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 2,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': '76398bba70a95e399d781a961c4fa06a',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:8382',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592984821.0187283],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 5.149699227059281e-184,
#     'id': '8da08aa3cec388d5964a17c324bd9c33',
#     'num_publications': 25.15637052038391,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0003699',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592984821.0186331],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 3.6633413916897996e-184,
#     'id': '9b2d58d2499d827d194969160fd61854',
#     'num_publications': 25.121100789527752,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0003699',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592883734.0799077],
#     'edge_source': ['cord19_scibite_v5'],
#     'enrichment_p': 3.8917225332691085e-09,
#     'id': '6dfcdcf38aebae004be0134938b718f2',
#     'num_publications': 0.8453600232892685,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scibite_v5'],
#     'source_id': 'CHEBI:50275',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 2,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': 'fdf8c945c14dbca6564f969ea567918e',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:50275',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592989756.9477856],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 5.673588203170735e-25,
#     'id': 'e45b6937a7ccfd5efc48a7f46df2103a',
#     'num_publications': 0.586488509289425,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'CHEBI:17650',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'count': 3,
#     'edge_source': 'https://www.drugbank.ca/covid-19',
#     'id': '0bec65fb831ddbedf776323dd197cc05',
#     'predicate_id': 'ROBOKOVID:in_clinical_trial_for',
#     'relation': 'in_clinical_trial_for',
#     'relation_label': 'in_clinical_trial_for',
#     'source_database': 'drugbank',
#     'source_id': 'CHEBI:17650',
#     'target_id': 'MONDO:0100096',
#     'type': 'in_clinical_trial_for',
#     'weight': 1},
#    {'ctime': [1592884093.1177442, 1592977662.621507],
#     'edge_source': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'enrichment_p': 8.708679749840965e-59,
#     'id': 'f674ed3268ec430961a1f6f638e0fd69',
#     'num_publications': 20.197508144756547,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH', 'SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to', 'related_to'],
#     'source_database': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'source_id': 'HP:0002094',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592977665.9724805],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 5.4442811087939534e-24,
#     'id': '4077f68824a70e18d6f777747c48496e',
#     'num_publications': 0.9292448123037186,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'HP:0002094',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592977662.6213896],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 2.2362074040911154e-56,
#     'id': 'c26b88cf20b7f8ee7fe2c6a4ee2ab275',
#     'num_publications': 19.704059170555595,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'HP:0002094',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592884107.527225, 1592977718.5094311],
#     'edge_source': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'enrichment_p': 5.959333843008381e-49,
#     'id': '643fdb270933cd61a955bdd179ad7c73',
#     'num_publications': 11.526271609286493,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH', 'SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to', 'related_to'],
#     'source_database': ['cord19_scibite_v5', 'cord19_scigraph_v7'],
#     'source_id': 'HP:0003326',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592977718.509311],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.999866019498415e-46,
#     'id': 'c60a718be22bec610056f8783bd29243',
#     'num_publications': 11.177060892450077,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'HP:0003326',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592884106.6981049],
#     'edge_source': ['cord19_scibite_v5'],
#     'enrichment_p': 3.205428505197073e-08,
#     'id': '1ab4bb5350a0e315b05708cf61348735',
#     'num_publications': 0.8567711662890748,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scibite_v5'],
#     'source_id': 'MONDO:0003019',
#     'target_id': 'MONDO:0100096',
#     'type': 'related_to',
#     'weight': 1},
#    {'ctime': [1592994028.5894465],
#     'edge_source': ['cord19_scigraph_v7'],
#     'enrichment_p': 1.4944647914641275e-26,
#     'id': '6ff38fffa4c6f0dcacc578327d518a21',
#     'num_publications': 0.495268703589563,
#     'predicate_id': 'owl:ObjectProperty',
#     'publications': [],
#     'relation': ['SEMMEDDB:ASSOCIATED_WITH'],
#     'relation_label': ['related_to'],
#     'source_database': ['cord19_scigraph_v7'],
#     'source_id': 'MONDO:0003019',
#     'target_id': 'CHEBI:4975',
#     'type': 'related_to',
#     'weight': 1},
#    {'edge_source': 'omnicorp.term_to_term',
#     'id': '08e1a7a3-dbb0-4ac4-9784-0cd2822c43f4',
#     'num_publications': 7,
#     'publications': [],
#     'source_database': 'omnicorp',
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0005478',
#     'type': 'literature_co-occurrence',
#     'weight': 1},
#    {'edge_source': 'omnicorp.term_to_term',
#     'id': '6d426fbf-56d8-4f22-b252-6f00c5d5457b',
#     'num_publications': 1,
#     'publications': [],
#     'source_database': 'omnicorp',
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0003019',
#     'type': 'literature_co-occurrence',
#     'weight': 1},
#    {'edge_source': 'omnicorp.term_to_term',
#     'id': 'c282432b-a290-4bc8-b517-cade68508e66',
#     'num_publications': 7,
#     'publications': [],
#     'source_database': 'omnicorp',
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0005009',
#     'type': 'literature_co-occurrence',
#     'weight': 1},
#    {'edge_source': 'omnicorp.term_to_term',
#     'id': 'af42f385-9091-44fa-b0fc-b4907f7480f3',
#     'num_publications': 4,
#     'publications': [],
#     'source_database': 'omnicorp',
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0004995',
#     'type': 'literature_co-occurrence',
#     'weight': 1},
#    {'edge_source': 'omnicorp.term_to_term',
#     'id': 'afdb420a-06c0-49a2-8ee7-ebee9c24902b',
#     'num_publications': 1,
#     'publications': [],
#     'source_database': 'omnicorp',
#     'source_id': 'CHEBI:4975',
#     'target_id': 'HP:0003326',
#     'type': 'literature_co-occurrence',
#     'weight': 1},
#    {'edge_source': 'omnicorp.term_to_term',
#     'id': '4d643f37-eb8e-477c-987d-d4c300aa9488',
#     'num_publications': 2,
#     'publications': [],
#     'source_database': 'omnicorp',
#     'source_id': 'CHEBI:4975',
#     'target_id': 'HP:0002094',
#     'type': 'literature_co-occurrence',
#     'weight': 1},
#    {'edge_source': 'omnicorp.term_to_term',
#     'id': '5788d46c-1189-4d4a-86e5-ae9215cc6470',
#     'num_publications': 13,
#     'publications': [],
#     'source_database': 'omnicorp',
#     'source_id': 'CHEBI:4975',
#     'target_id': 'MONDO:0005249',
#     'type': 'literature_co-occurrence',
#     'weight': 1},
#    {'edge_source': 'omnicorp.term_to_term',
#     'id': 'a15cfe68-89fb-4e9d-a1a4-2bbc502d75e5',
#     'num_publications': 1,
# ...
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['-4688125966447552416', '-4433887868964610189'],
#      'weight': 0.0}],
#    'score': 0.11814601337863205},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['MONDO:0003699', 'MONDO:0004995'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CARO:0000006']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CARO:0000006']},
#     {'qg_id': 's9',
#      'kg_id': ['af42f385-9091-44fa-b0fc-b4907f7480f3'],
#      'weight': 0.0}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['3a2a0ef902c24176627a0fe0a4d8b08d',
#       '9b2d58d2499d827d194969160fd61854',
#       '8da08aa3cec388d5964a17c324bd9c33',
#       'b8fd8b1f41940990aa64c864bbd11673'],
#      'weight': 0.0},
#     {'qg_id': 'bc',
#      'kg_id': ['a2178d4e628eefdc535e66edd7b15e52',
#       '84aa4a49db52be6a1be71060f32b219c'],
#      'weight': 0.0},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['139494845478054779', '-2603666239126064856'],
#      'weight': 0.0}],
#    'score': 0.11814601337863205},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['MONDO:0004900', 'HP:0002098'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CARO:0000003']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CARO:0000003']},
#     {'qg_id': 's36',
#      'kg_id': ['2323b74d-7054-4ca4-b0d1-f94354639b24'],
#      'weight': 5.283676206091492e-05}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['621c2897d9cd436ad9d0a0a5d1b7fd44',
#       'a0ab13c777e2d23b0ea6f82a2d06dd88',
#       'f9ae048208c0ca25ac0944ec49880d80',
#       '7575a15c9db427fcff8a64e062782e7a'],
#      'weight': 5.283676206091492e-05},
#     {'qg_id': 'bc',
#      'kg_id': ['97ba863e0634a258a7bd4f13f5c2154b',
#       'b507d7530765741a28afd91562ad49d1'],
#      'weight': 5.283676206091492e-05},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['-2718810720998364155', '-8971728799482154248'],
#      'weight': 5.283676206091492e-05}],
#    'score': 0.08932813820800495},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['MONDO:0004900', 'HP:0002098'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CARO:0000006']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CARO:0000006']},
#     {'qg_id': 's36',
#      'kg_id': ['2323b74d-7054-4ca4-b0d1-f94354639b24'],
#      'weight': 5.283676206091492e-05}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['621c2897d9cd436ad9d0a0a5d1b7fd44',
#       'a0ab13c777e2d23b0ea6f82a2d06dd88',
#       'f9ae048208c0ca25ac0944ec49880d80',
#       '7575a15c9db427fcff8a64e062782e7a'],
#      'weight': 5.283676206091492e-05},
#     {'qg_id': 'bc',
#      'kg_id': ['97ba863e0634a258a7bd4f13f5c2154b',
#       'b507d7530765741a28afd91562ad49d1'],
#      'weight': 5.283676206091492e-05},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['2120196762134423268', '-940707732502260111'],
#      'weight': 5.283676206091492e-05}],
#    'score': 0.08932813820800495},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['MONDO:0004900', 'HP:0002098'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CARO:0000011']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CARO:0000011']},
#     {'qg_id': 's36',
#      'kg_id': ['2323b74d-7054-4ca4-b0d1-f94354639b24'],
#      'weight': 5.283676206091492e-05}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['621c2897d9cd436ad9d0a0a5d1b7fd44',
#       'a0ab13c777e2d23b0ea6f82a2d06dd88',
#       'f9ae048208c0ca25ac0944ec49880d80',
#       '7575a15c9db427fcff8a64e062782e7a'],
#      'weight': 5.283676206091492e-05},
#     {'qg_id': 'bc',
#      'kg_id': ['97ba863e0634a258a7bd4f13f5c2154b',
#       'b507d7530765741a28afd91562ad49d1'],
#      'weight': 5.283676206091492e-05},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['-8566518175744867916', '-5641739971486932671'],
#      'weight': 5.283676206091492e-05}],
#    'score': 0.08932813820800495},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:15365', 'CHEBI:50275'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:134674']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:134674']},
#     {'qg_id': 's50',
#      'kg_id': ['1bb7f5b7-9bdd-4d2a-b3a5-d84d60d43a55'],
#      'weight': 0.0009535233993085424},
#     {'qg_id': 's54',
#      'kg_id': ['5855e1c3-8116-43dd-bdb5-c071a908adbf'],
#      'weight': 0.0045732571755316975}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['fdf8c945c14dbca6564f969ea567918e',
#       '37df1bf232ea833789b40a3153d8b555'],
#      'weight': 0.0045732571755316975},
#     {'qg_id': 'bc',
#      'kg_id': ['6dfcdcf38aebae004be0134938b718f2',
#       'c969c528d3617853bb34aa247ed9e95d'],
#      'weight': 0.0045732571755316975},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['-2190286746515512574', '-1053146665203771683'],
#      'weight': 0.0045732571755316975}],
#    'score': 0.08522460758413297},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:15365', 'CHEBI:50275'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:134674']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:134674']},
#     {'qg_id': 's50',
#      'kg_id': ['1bb7f5b7-9bdd-4d2a-b3a5-d84d60d43a55'],
#      'weight': 0.0009535233993085424},
#     {'qg_id': 's54',
#      'kg_id': ['5855e1c3-8116-43dd-bdb5-c071a908adbf'],
#      'weight': 0.0045732571755316975}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['fdf8c945c14dbca6564f969ea567918e',
#       '37df1bf232ea833789b40a3153d8b555'],
#      'weight': 0.0045732571755316975},
#     {'qg_id': 'bc',
#      'kg_id': ['6dfcdcf38aebae004be0134938b718f2',
#       'c969c528d3617853bb34aa247ed9e95d'],
#      'weight': 0.0045732571755316975},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['8469301250082076406', '1172003076696818769'],
#      'weight': 0.0045732571755316975}],
#    'score': 0.08522460758413297},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:15365', 'CHEBI:50275'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:134674']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:134674']},
#     {'qg_id': 's50',
#      'kg_id': ['1bb7f5b7-9bdd-4d2a-b3a5-d84d60d43a55'],
#      'weight': 0.0009535233993085424},
#     {'qg_id': 's54',
#      'kg_id': ['5855e1c3-8116-43dd-bdb5-c071a908adbf'],
#      'weight': 0.0045732571755316975}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['fdf8c945c14dbca6564f969ea567918e',
#       '37df1bf232ea833789b40a3153d8b555'],
#      'weight': 0.0045732571755316975},
#     {'qg_id': 'bc',
#      'kg_id': ['6dfcdcf38aebae004be0134938b718f2',
#       'c969c528d3617853bb34aa247ed9e95d'],
#      'weight': 0.0045732571755316975},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['1600037169806937829', '623106266346510330'],
#      'weight': 0.0045732571755316975}],
#    'score': 0.08522460758413297},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:8382', 'CHEBI:17650'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:139588']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:139588']},
#     {'qg_id': 's48',
#      'kg_id': ['47b4344d-a829-4f3c-bb13-18dcf50b1ce3'],
#      'weight': 4.390150301292195e-06},
#     {'qg_id': 's52',
#      'kg_id': ['24d07c03-f14a-4f24-bb25-7df61c928332'],
#      'weight': 0.0}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['76398bba70a95e399d781a961c4fa06a',
#       '0bec65fb831ddbedf776323dd197cc05'],
#      'weight': 0.0},
#     {'qg_id': 'bc',
#      'kg_id': ['c625e04a5df86b5bb725f89028c741ff',
#       'e45b6937a7ccfd5efc48a7f46df2103a'],
#      'weight': 0.0},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['3687342266628251526', '-7536289991897952671'],
#      'weight': 0.0}],
#    'score': 0.08331650636606011},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:8382', 'CHEBI:17650'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:139590']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:139590']},
#     {'qg_id': 's48',
#      'kg_id': ['47b4344d-a829-4f3c-bb13-18dcf50b1ce3'],
#      'weight': 4.390150301292195e-06},
#     {'qg_id': 's52',
#      'kg_id': ['24d07c03-f14a-4f24-bb25-7df61c928332'],
#      'weight': 0.0}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['76398bba70a95e399d781a961c4fa06a',
#       '0bec65fb831ddbedf776323dd197cc05'],
#      'weight': 0.0},
#     {'qg_id': 'bc',
#      'kg_id': ['c625e04a5df86b5bb725f89028c741ff',
#       'e45b6937a7ccfd5efc48a7f46df2103a'],
#      'weight': 0.0},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['1220600162988815261', '-3792741273445391134'],
#      'weight': 0.0}],
#    'score': 0.08331650636606011},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:8382', 'CHEBI:17650'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:139592']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:139592']},
#     {'qg_id': 's48',
#      'kg_id': ['47b4344d-a829-4f3c-bb13-18dcf50b1ce3'],
#      'weight': 4.390150301292195e-06},
#     {'qg_id': 's52',
#      'kg_id': ['24d07c03-f14a-4f24-bb25-7df61c928332'],
#      'weight': 0.0}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['76398bba70a95e399d781a961c4fa06a',
#       '0bec65fb831ddbedf776323dd197cc05'],
#      'weight': 0.0},
#     {'qg_id': 'bc',
#      'kg_id': ['c625e04a5df86b5bb725f89028c741ff',
#       'e45b6937a7ccfd5efc48a7f46df2103a'],
#      'weight': 0.0},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['-2470314591486861522', '-1866067072786687303'],
#      'weight': 0.0}],
#    'score': 0.08331650636606011},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:8382', 'CHEBI:17650'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:15734']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:15734']},
#     {'qg_id': 's48',
#      'kg_id': ['47b4344d-a829-4f3c-bb13-18dcf50b1ce3'],
#      'weight': 4.390150301292195e-06},
#     {'qg_id': 's52',
#      'kg_id': ['24d07c03-f14a-4f24-bb25-7df61c928332'],
#      'weight': 0.0}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['76398bba70a95e399d781a961c4fa06a',
#       '0bec65fb831ddbedf776323dd197cc05'],
#      'weight': 0.0},
#     {'qg_id': 'bc',
#      'kg_id': ['c625e04a5df86b5bb725f89028c741ff',
#       'e45b6937a7ccfd5efc48a7f46df2103a'],
#      'weight': 0.0},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['3700691587253754686', '-6182611819473416087'],
#      'weight': 0.0}],
#    'score': 0.08331650636606011},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:8382', 'CHEBI:41879', 'CHEBI:17650'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:17087']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:17087']},
#     {'qg_id': 's48',
#      'kg_id': ['47b4344d-a829-4f3c-bb13-18dcf50b1ce3'],
#      'weight': 4.390150301292195e-06},
#     {'qg_id': 's58',
#      'kg_id': ['c9b02657-c7d5-4f4f-9a2e-fb3c1600827a'],
#      'weight': 0.0006769336758347677},
#     {'qg_id': 's52',
#      'kg_id': ['24d07c03-f14a-4f24-bb25-7df61c928332'],
#      'weight': 0.0}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['ea0ac9ce749f81122601bc5e874f74bc',
#       '76398bba70a95e399d781a961c4fa06a',
#       '0bec65fb831ddbedf776323dd197cc05'],
#      'weight': 0.0},
#     {'qg_id': 'bc',
#      'kg_id': ['c625e04a5df86b5bb725f89028c741ff',
#       'e45b6937a7ccfd5efc48a7f46df2103a',
#       '3362f77d3da71d2a78c1fa2c2a377777'],
#      'weight': 0.0},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['-5201758249395848994',
#       '6916302458512475986',
#       '-7798780730364555767'],
#      'weight': 0.0}],
#    'score': 0.08331650636606011},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:41879', 'CHEBI:17650'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:18059']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:18059']},
#     {'qg_id': 's58',
#      'kg_id': ['c9b02657-c7d5-4f4f-9a2e-fb3c1600827a'],
#      'weight': 0.0006769336758347677},
#     {'qg_id': 's52',
#      'kg_id': ['24d07c03-f14a-4f24-bb25-7df61c928332'],
#      'weight': 0.0}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['ea0ac9ce749f81122601bc5e874f74bc',
#       '0bec65fb831ddbedf776323dd197cc05'],
#      'weight': 0.0},
#     {'qg_id': 'bc',
#      'kg_id': ['e45b6937a7ccfd5efc48a7f46df2103a',
#       '3362f77d3da71d2a78c1fa2c2a377777'],
#      'weight': 0.0},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['-2942399152370672382', '7716312979587246478'],
#      'weight': 0.0}],
#    'score': 0.08329712574548896},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:17650', 'CHEBI:8382', 'CHEBI:41879', 'CHEBI:135765'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:18059']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:18059']},
#     {'qg_id': 's48',
#      'kg_id': ['47b4344d-a829-4f3c-bb13-18dcf50b1ce3'],
#      'weight': 4.390150301292195e-06},
#     {'qg_id': 's58',
#      'kg_id': ['c9b02657-c7d5-4f4f-9a2e-fb3c1600827a'],
#      'weight': 0.0006769336758347677},
#     {'qg_id': 's52',
#      'kg_id': ['24d07c03-f14a-4f24-bb25-7df61c928332'],
#      'weight': 0.0}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['0bec65fb831ddbedf776323dd197cc05',
#       'ea0ac9ce749f81122601bc5e874f74bc',
#       '76398bba70a95e399d781a961c4fa06a',
#       '840140149eadac3be9345260d78fc8be'],
#      'weight': 0.0},
#     {'qg_id': 'bc',
#      'kg_id': ['ebf691afed5e5d1f15efb4c068868544',
#       'c625e04a5df86b5bb725f89028c741ff',
#       'e45b6937a7ccfd5efc48a7f46df2103a',
#       '3362f77d3da71d2a78c1fa2c2a377777'],
#      'weight': 0.0},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['-4879778730313099826',
#       '1254135017337749373',
#       '-82361852722734141',
#       '-3835504429442567998'],
#      'weight': 0.0}],
#    'score': 0.08582617350793509},
#   {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#     {'qg_id': 'b',
#      'kg_id': ['CHEBI:8382', 'CHEBI:41879'],
#      'coalescence_method': 'graph_enrichment',
#      'p_value': 0.0,
#      'enriched_nodes': ['CHEBI:20156']},
#     {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#     {'qg_id': 'extra_qn_0', 'kg_id': ['CHEBI:20156']},
#     {'qg_id': 's48',
#      'kg_id': ['47b4344d-a829-4f3c-bb13-18dcf50b1ce3'],
#      'weight': 4.390150301292195e-06},
#     {'qg_id': 's58',
#      'kg_id': ['c9b02657-c7d5-4f4f-9a2e-fb3c1600827a'],
#      'weight': 0.0006769336758347677}],
#    'edge_bindings': [{'qg_id': 'ab',
#      'kg_id': ['ea0ac9ce749f81122601bc5e874f74bc',
#       '76398bba70a95e399d781a961c4fa06a'],
#      'weight': 0.0006769336758347677},
#     {'qg_id': 'bc',
#      'kg_id': ['c625e04a5df86b5bb725f89028c741ff',
#       '3362f77d3da71d2a78c1fa2c2a377777'],
#      'weight': 0.0006769336758347677},
#     {'qg_id': 'extra_qe_0',
#      'kg_id': ['5172457417880471537', '6759344721286681562'],
#      'weight': 0.0006769336758347677}],
#    'score': 0.08331650636606011}]}

# %%
gd['results'][1]
# Out:
# {'node_bindings': [{'qg_id': 'a', 'kg_id': ['MONDO:0100096']},
#   {'qg_id': 'b',
#    'kg_id': ['MONDO:0005009', 'MONDO:0003019'],
#    'coalescence_method': 'graph_enrichment',
#    'p_value': 0.0,
#    'enriched_nodes': ['CARO:0000006']},
#   {'qg_id': 'c', 'kg_id': ['CHEBI:4975']},
#   {'qg_id': 'extra_qn_0', 'kg_id': ['CARO:0000006']},
#   {'qg_id': 's5',
#    'kg_id': ['c282432b-a290-4bc8-b517-cade68508e66'],
#    'weight': 0.00025229939954596325},
#   {'qg_id': 's3',
#    'kg_id': ['6d426fbf-56d8-4f22-b252-6f00c5d5457b'],
#    'weight': 0.0}],
#  'edge_bindings': [{'qg_id': 'ab',
#    'kg_id': ['1ab4bb5350a0e315b05708cf61348735',
#     '8af37d23e5428c5a1cb8547385f6772c'],
#    'weight': 0.0},
#   {'qg_id': 'bc',
#    'kg_id': ['6ff38fffa4c6f0dcacc578327d518a21',
#     '8872e78619d787c6ebede9c092e74db5',
#     '97d2d4d898611e086700cdd83d8e97fd',
#     '5d1a7a8fad6fa52d4eec8857c540a664'],
#    'weight': 0.0},
#   {'qg_id': 'extra_qe_0',
#    'kg_id': ['2353862735879336843', '-6970308096730686244'],
#    'weight': 0.0}],
#  'score': 0.14508095937591511}

# %%
names = {}
for node in gd['knowledge_graph']['nodes']:
    names[node['id']] = node['name']
r=0
for result in gd['results']:
    for nb in result['node_bindings']:
        if nb['qg_id'].startswith('extra'):
            kgid = nb['kg_id'][0]
            print(r, kgid, names[kgid])
    r += 1
# Out:
# 0 CARO:0000003
# 1 CARO:0000006
# 2 CARO:0000011
# 3 CARO:0000003
# 4 CARO:0000003
# 5 CARO:0000006
# 6 CARO:0000006
# 7 CARO:0000003
# 8 CARO:0000003
# 9 CARO:0000006
# 10 CARO:0000006
# 11 CARO:0000003
# 12 CARO:0000006
# 13 CARO:0000011
# 14 CHEBI:134674 Yosprala
# 15 CHEBI:134674 Yosprala
# 16 CHEBI:134674 Yosprala
# 17 CHEBI:139588 alpha-hydroxy ketone
# 18 CHEBI:139590 primary alpha-hydroxy ketone
# 19 CHEBI:139592 tertiary alpha-hydroxy ketone
# 20 CHEBI:15734 primary alcohol
# 21 CHEBI:17087 ketone
# 22 CHEBI:18059 lipid
# 23 CHEBI:18059 lipid
# 24 CHEBI:20156 3-oxo-Delta(1) steroid

# %%
def create_threehop_message():
    query_graph = {
    "nodes": [
        {
            #Covid-19
            "id": "a",
            "type": "disease",
            "curie": "MONDO:0100096"
        },
        {
            "id": "b",
            "type": "gene"
        },
        {
            "id": "c",
            "type": "named_thing"
        },
        {
            #Famotidine
            "id": "d",
            "type": "chemical_substance",
            "curie": "CHEBI:4975"
        }
    ],
    "edges": [
        {
            "id": "ab",
            "source_id": "a",
            "target_id": "b"
        },
        {
            "id": "bc",
            "source_id": "c",
            "target_id": "b"
        },
        {
            "id": "cd",
            "source_id": "c",
            "target_id": "d"
        }
    ]
    }
    message = {"message": {"query_graph": query_graph,
                       'knowledge_graph':{'url': 'bolt://stars-k6.edc.renci.org:31333',
            'credentials': {
                'username': 'neo4j',
                'password': 'ncatsgamma',
            },}, 
                           'results':[{"node_bindings": [],"edge_bindings": []}]}}
    return message

# %%
message3 = create_threehop_message()
robokop_result2 = robokop.pipeline(message3,full=True)

# %%
print (len(robokop_result2['results']))
# Out:
# 2062

# %%
params = {'method':'graph'}
g_r2 = requests.post(url,json=robokop_result2,params=params)
print(g_r2.status_code)
graph_result2 = g_r2.json()
print( len(graph_result2['results']))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-e676f0d31540> in <module>
#       1 params = {'method':'graph'}
# ----> 2 g_r2 = requests.post(url,json=robokop_result2,params=params)
#       3 print(g_r2.status_code)
#       4 graph_result2 = g_r2.json()
#       5 print( len(graph_result2['results']))
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/envs/translator/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/anaconda3/envs/translator/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/anaconda3/envs/translator/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/anaconda3/envs/translator/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~/anaconda3/envs/translator/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
with open('bigger.json','w') as outf:
    json.dump(robokop_result2,outf,indent=2)
