# %% [markdown]
# # Famotidine Covid
#
# This is a test case to see whether Answer Merging helps with the arbitrary query problem. The problem is: I want to know the most interesting way in which these two entities are related.  What is it?  One option is to do question rewriting.  But another (this one) is to general queries and then work on merging them.

# %%
import requests
import json
import time
import pandas as pd

#GammaViewer available from https://github.com/ranking-agent/gamma-viewer
from GammaViewer import GammaViewer
from IPython.display import display

# %%
def getlabel(curie):
    url = 'https://nodenormalization-sri.renci.org/get_normalized_nodes'
    try:
        r = requests.get(url,params={'curie':curie}).json()
        return r[curie]['id']['label']
    except:
        return ''

class RobokopMessenger:
    def __init__(self):
        self.url = 'http://stars-k6.edc.renci.org:32140'
    def pipeline(self,request,full = True):
        #normalize question
        response = requests.post( f'{self.url}/normalize', json=request )
        normalized = response.json()
        
        #answer question
        request = { 'message': normalized, }
        response = requests.post( f'{self.url}/answer', json=request )
        answered = response.json()
        if not full:
            return answered
        
        #Yank
        request = { 'message': answered, }
        response = requests.post( f'{self.url}/yank', json=request )
        filled = response.json()
        
        #support
        request = { 'message': filled, }
        response = requests.post( 'http://robokop.renci.org:4868/support', json=request )
        supported = response.json()
        #weight
        request = { 'message': supported, }
        response = requests.post( 'http://robokop.renci.org:4868/weight_correctness', json=request )
        weighted = response.json()
        #score
        request = { 'message': weighted, }
        response = requests.post( 'http://robokop.renci.org:4868/score', json=request )
        scored = response.json()
        return scored

    
robokop=RobokopMessenger()

# %%
def create_message():
    query_graph = {
    "nodes": [
        {
            #Covid-19
            "id": "a",
            "type": "disease",
            "curie": "MONDO:0100096"
        },
        {
            "id": "b",
            "type": "named_thing"
        },
        {
            #Famotidine
            "id": "c",
            "type": "chemical_substance",
            "curie": "CHEBI:4975"
        }
    ],
    "edges": [
        {
            "id": "ab",
            "source_id": "a",
            "target_id": "b"
        },
        {
            "id": "bc",
            "source_id": "c",
            "target_id": "b"
        }
    ]
    }
    message = {"message": {"query_graph": query_graph,
                       'knowledge_graph':{'url': 'bolt://stars-k6.edc.renci.org:31333',
            'credentials': {
                'username': 'neo4j',
                'password': 'ncatsgamma',
            },}, 
                           'results':[{"node_bindings": [],"edge_bindings": []}]}}
    return message

# %%
message = create_message()
react_component = GammaViewer(props={"data":message['message']})
display(react_component)

# %%
robokop_result = robokop.pipeline(message,full=True)
print( json.dumps(robokop_result,indent=2))
# Out:
# {
#   "knowledge_graph": {
#     "edges": [
#       {
#         "ctime": [
#           1592973258.6295419
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 7.200162544618264e-26,
#         "id": "6495101038d3ebd2aef30675f0bef227",
#         "num_publications": 0.8943779167033549,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "CHEBI:29320",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "count": 3,
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "id": "4c4115b44968337424dd20dba4f70e0c",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "relation": "in_clinical_trial_for",
#         "relation_label": "in_clinical_trial_for",
#         "source_database": "drugbank",
#         "source_id": "CHEBI:29320",
#         "target_id": "MONDO:0100096",
#         "type": "in_clinical_trial_for",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883766.4699512,
#           1592988131.9177973
#         ],
#         "edge_source": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 1.3043294894440849e-36,
#         "id": "d8680bb5602b6b89d26a25b24e2c095b",
#         "num_publications": 0.6291631201510571,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH",
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to",
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "CHEBI:91766",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "count": 1,
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "id": "421161f1bf8904ea7ee3e2133c21d58c",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "relation": "in_clinical_trial_for",
#         "relation_label": "in_clinical_trial_for",
#         "source_database": "drugbank",
#         "source_id": "CHEBI:91766",
#         "target_id": "MONDO:0100096",
#         "type": "in_clinical_trial_for",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592978071.666772
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 5.472205453104307e-26,
#         "id": "cb3ea2a62b1f66ce84418e8a3be0e8ef",
#         "num_publications": 0.9911346893252325,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "CHEBI:27140",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592978068.1861784
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 4.574130896612511e-21,
#         "id": "33c1128df44678aa7e2c4b00bef7ed80",
#         "num_publications": 11.816381233306911,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "CHEBI:27140",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592986981.0051198
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 2.133443398140935e-31,
#         "id": "3362f77d3da71d2a78c1fa2c2a377777",
#         "num_publications": 0.7182144149961355,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "CHEBI:41879",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "count": 4,
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "id": "ea0ac9ce749f81122601bc5e874f74bc",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "relation": "in_clinical_trial_for",
#         "relation_label": "in_clinical_trial_for",
#         "source_database": "drugbank",
#         "source_id": "CHEBI:41879",
#         "target_id": "MONDO:0100096",
#         "type": "in_clinical_trial_for",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883732.5642235
#         ],
#         "edge_source": [
#           "cord19_scibite_v5"
#         ],
#         "enrichment_p": 2.570516884443281e-05,
#         "id": "ebf691afed5e5d1f15efb4c068868544",
#         "num_publications": 0.8929597565218225,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scibite_v5"
#         ],
#         "source_id": "CHEBI:135765",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "count": 1,
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "id": "840140149eadac3be9345260d78fc8be",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "relation": "in_clinical_trial_for",
#         "relation_label": "in_clinical_trial_for",
#         "source_database": "drugbank",
#         "source_id": "CHEBI:135765",
#         "target_id": "MONDO:0100096",
#         "type": "in_clinical_trial_for",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592884086.4851
#         ],
#         "edge_source": [
#           "cord19_scibite_v5"
#         ],
#         "enrichment_p": 4.541758585377523e-05,
#         "id": "8af37d23e5428c5a1cb8547385f6772c",
#         "num_publications": 0.896040175025774,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scibite_v5"
#         ],
#         "source_id": "MONDO:0005009",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592981172.099994
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 1.6989478782165154e-28,
#         "id": "97d2d4d898611e086700cdd83d8e97fd",
#         "num_publications": 0.8548858755735571,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0005009",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883708.3244195,
#           1592997726.0604272
#         ],
#         "edge_source": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 1.1546909482235062e-21,
#         "id": "37894ba3dd3eb368addfaa8b2bdd3339",
#         "num_publications": 0.5792702493811942,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH",
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to",
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "CHEBI:2676",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "count": 1,
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "id": "38463c3f2f4fa6107f8ed8e342e9c4b0",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "relation": "in_clinical_trial_for",
#         "relation_label": "in_clinical_trial_for",
#         "source_database": "drugbank",
#         "source_id": "CHEBI:2676",
#         "target_id": "MONDO:0100096",
#         "type": "in_clinical_trial_for",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592884106.6600294,
#           1592973733.1272883
#         ],
#         "edge_source": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 5.7223013649918366e-55,
#         "id": "6f1af85dfe9fca1dbd398d8eb7fd82ff",
#         "num_publications": 17.21551759560917,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH",
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to",
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0021113",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592973733.1271975
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 1.0042746400658484e-55,
#         "id": "21e0fb31f5500329d0e145e1a1c1d73e",
#         "num_publications": 17.2972977996928,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0021113",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592998728.6675196
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 1.8114549349702598e-21,
#         "id": "c628d14b6df7def8adc0ef83e9b05bf1",
#         "num_publications": 1.8800446127204955,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0005478",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592998728.5039413
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 8.01600147293797e-22,
#         "id": "eb2b32c3a22ebcefac4d52819d41db51",
#         "num_publications": 1.8947565378180857,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0005478",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592998728.5023954
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 0.0,
#         "id": "91d70bc5d586a986d737b57b60f58470",
#         "num_publications": 914.567306507,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.4206164
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "fab6806d5b0df8e30151ea1996f1801b",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0045057",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.5563283
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "435e08ee81641e965b42ff260d8ff0a2",
#         "notes": "https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0021146",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.4094603
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "68056e92b90c88ad659225911cff2241",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0001673",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.2349684
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "f9ae048208c0ca25ac0944ec49880d80",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "HP:0002098",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.232173
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "073a448000db4534afdc5852e8827c6b",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0015137",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.493145
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "7575a15c9db427fcff8a64e062782e7a",
#         "notes": "https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0004900",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.4271076
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "a36a8e13acb3df3e2fbaa557a64b85c7",
#         "notes": "https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "HP:0003326",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.424095
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "e58a3b85f45f7ad8fc9c9865a690d844",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "HP:0002094",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.4206164
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "9f4df0444db2a3ffc09c25e8b0713578",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0045057",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.5563283
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "39bf57a77e9522c8643e2a4bdb6ccd8f",
#         "notes": "https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0021146",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.4094603
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "449bd7a67b7c8dcec04ed68e60170c65",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0001673",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.2349684
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "621c2897d9cd436ad9d0a0a5d1b7fd44",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "HP:0002098",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.232173
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "4b5cc0ba33025b8d27e1ea9c61d24545",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0015137",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.493145
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "a0ab13c777e2d23b0ea6f82a2d06dd88",
#         "notes": "https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0004900",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.4271076
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "d28135ab3f9c8ecb3bad81929bd68357",
#         "notes": "https://www.cebm.net/covid-19/covid-19-signs-and-symptoms-tracker/",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "HP:0003326",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592883297.424095
#         ],
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "id": "3faaa74ce473aca1932f5d91ff7238db",
#         "notes": "Covid symptom tracker",
#         "predicate_id": "RO:0002200",
#         "publications": [],
#         "relation": [
#           "RO:0002200"
#         ],
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "source_id": "MONDO:0100096",
#         "target_id": "HP:0002094",
#         "type": "has_phenotype",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592982376.5923533
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 4.4987601399449174e-38,
#         "id": "30fbd2d5b20760ca28f0a501143f2212",
#         "num_publications": 1.3086363769774882,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0001673",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1593000703.8206472
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 8.578597271860192e-28,
#         "id": "11a0002c5b1939093e85a34dd17eec0d",
#         "num_publications": 0.5279196384021602,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "CHEBI:16899",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "count": 1,
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "id": "8334c5cbc77f948b76c66df621baa667",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "relation": "in_clinical_trial_for",
#         "relation_label": "in_clinical_trial_for",
#         "source_database": "drugbank",
#         "source_id": "CHEBI:16899",
#         "target_id": "MONDO:0100096",
#         "type": "in_clinical_trial_for",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1585042796.1710408
#         ],
#         "edge_source": [
#           "ctd.disease_to_chemical"
#         ],
#         "id": "7325ed3030aa9e947dd4064104317cfc",
#         "predicate_id": "RO:0002326",
#         "publications": [
#           "PMID:19358226"
#         ],
#         "relation": [
#           "CTD:marker_mechanism"
#         ],
#         "relation_label": [
#           "marker_mechanism"
#         ],
#         "source_database": [
#           "ctd"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005478",
#         "type": "contributes_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1585042672.8032074
#         ],
#         "edge_source": [
#           "ctd.disease_to_chemical"
#         ],
#         "id": "908ca5052b017f4ea79f769b5c3a5897",
#         "predicate_id": "RO:0002326",
#         "publications": [
#           "PMID:3243179",
#           "PMID:9545163"
#         ],
#         "relation": [
#           "CTD:marker_mechanism"
#         ],
#         "relation_label": [
#           "marker_mechanism"
#         ],
#         "source_database": [
#           "ctd"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0045057",
#         "type": "contributes_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1585046178.4621778
#         ],
#         "edge_source": [
#           "ctd.disease_to_chemical"
#         ],
#         "id": "1b344638fcb4da3c3c3f84e0fa30fb0b",
#         "predicate_id": "RO:0002326",
#         "publications": [
#           "PMID:2563629"
#         ],
#         "relation": [
#           "CTD:marker_mechanism"
#         ],
#         "relation_label": [
#           "marker_mechanism"
#         ],
#         "source_database": [
#           "ctd"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0021146",
#         "type": "contributes_to",
#         "weight": 1
#       },
#       {
#         "case_count": 7,
#         "ctime": [
#           1587851144.023563
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "2fcb26c5435fda1b99c632c3e5e99efd",
#         "predicate_id": "biolink:causes_adverse_event",
#         "prr": 3.6926400000000004,
#         "publications": [],
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "ror": 3.69276,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005379",
#         "type": "causes_adverse_event",
#         "weight": 1
#       },
#       {
#         "case_count": 86,
#         "ctime": [
#           1587851143.9913058
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "cc99bb33ef8f58c50731d908ae6e750d",
#         "predicate_id": "biolink:causes_adverse_event",
#         "prr": 2.45513,
#         "publications": [],
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "ror": 2.4559599999999997,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005478",
#         "type": "causes_adverse_event",
#         "weight": 1
#       },
#       {
#         "case_count": 90,
#         "ctime": [
#           1587851143.9910216
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "da825870d445b043d8c03cde137e1499",
#         "predicate_id": "biolink:causes_adverse_event",
#         "prr": 1.35095,
#         "publications": [],
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "ror": 1.3511600000000001,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005249",
#         "type": "causes_adverse_event",
#         "weight": 1
#       },
#       {
#         "case_count": 160,
#         "ctime": [
#           1587851143.9883249
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "26681dad7296fe33215922a961392821",
#         "predicate_id": "biolink:causes_adverse_event",
#         "prr": 2.0255099999999997,
#         "publications": [],
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "ror": 2.02659,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0006502",
#         "type": "causes_adverse_event",
#         "weight": 1
#       },
#       {
#         "case_count": 214,
#         "ctime": [
#           1587851143.9871805
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "1e4dfcec8da6409799fb897f6e02a746",
#         "predicate_id": "biolink:causes_adverse_event",
#         "prr": 1.85444,
#         "publications": [],
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "ror": 1.85565,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0045057",
#         "type": "causes_adverse_event",
#         "weight": 1
#       },
#       {
#         "case_count": 328,
#         "ctime": [
#           1587851143.986168
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "8872e78619d787c6ebede9c092e74db5",
#         "predicate_id": "biolink:causes_adverse_event",
#         "prr": 1.2686600000000001,
#         "publications": [],
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "ror": 1.26925,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005009",
#         "type": "causes_adverse_event",
#         "weight": 1
#       },
#       {
#         "case_count": 336,
#         "ctime": [
#           1587851143.986006
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "5d1a7a8fad6fa52d4eec8857c540a664",
#         "predicate_id": "biolink:causes_adverse_event",
#         "prr": 1.50962,
#         "publications": [],
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "ror": 1.51076,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0003019",
#         "type": "causes_adverse_event",
#         "weight": 1
#       },
#       {
#         "case_count": 524,
#         "ctime": [
#           1587851143.985148
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "a72584a4e86423d6d94314f0bce9ddc5",
#         "predicate_id": "biolink:causes_adverse_event",
#         "prr": 1.59875,
#         "publications": [],
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "ror": 1.60084,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0021113",
#         "type": "causes_adverse_event",
#         "weight": 1
#       },
#       {
#         "case_count": 1555,
#         "ctime": [
#           1587851143.9842718
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "2df290232bf3d30a27ad874836d05262",
#         "predicate_id": "biolink:causes_adverse_event",
#         "prr": 1.4644,
#         "publications": [],
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "ror": 1.4692399999999999,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0015137",
#         "type": "causes_adverse_event",
#         "weight": 1
#       },
#       {
#         "case_count": 320,
#         "ctime": [
#           1587872048.4022918
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "7439d7827535887b5a70c9c947bc6450",
#         "predicate_id": "RO:0002599",
#         "prr": 0.70729,
#         "publications": [],
#         "relation": [
#           "RO:0002599"
#         ],
#         "relation_label": [
#           "prevents"
#         ],
#         "ror": 0.70667,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "HP:0003326",
#         "type": "prevents",
#         "weight": 1
#       },
#       {
#         "case_count": 463,
#         "ctime": [
#           1587872048.4015822
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "08fad98cd9189aca091f94ce1263db39",
#         "predicate_id": "RO:0002599",
#         "prr": 0.7732100000000001,
#         "publications": [],
#         "relation": [
#           "RO:0002599"
#         ],
#         "relation_label": [
#           "prevents"
#         ],
#         "ror": 0.77251,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "HP:0012735",
#         "type": "prevents",
#         "weight": 1
#       },
#       {
#         "case_count": 1293,
#         "ctime": [
#           1587872048.3996162
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "b507d7530765741a28afd91562ad49d1",
#         "predicate_id": "RO:0002599",
#         "prr": 0.83129,
#         "publications": [],
#         "relation": [
#           "RO:0002599"
#         ],
#         "relation_label": [
#           "prevents"
#         ],
#         "ror": 0.82983,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "HP:0002098",
#         "type": "prevents",
#         "weight": 1
#       },
#       {
#         "case_count": 65,
#         "ctime": [
#           1587851143.9932017
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "84aa4a49db52be6a1be71060f32b219c",
#         "predicate_id": "RO:0002599",
#         "prr": 0.72951,
#         "publications": [],
#         "relation": [
#           "RO:0002599"
#         ],
#         "relation_label": [
#           "prevents"
#         ],
#         "ror": 0.72939,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0004995",
#         "type": "prevents",
#         "weight": 1
#       },
#       {
#         "case_count": 424,
#         "ctime": [
#           1587851143.985526
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "8183f213914fbca4a1ada57f34367e93",
#         "predicate_id": "RO:0002599",
#         "prr": 0.76758,
#         "publications": [],
#         "relation": [
#           "RO:0002599"
#         ],
#         "relation_label": [
#           "prevents"
#         ],
#         "ror": 0.7669199999999999,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0045057",
#         "type": "prevents",
#         "weight": 1
#       },
#       {
#         "case_count": 867,
#         "ctime": [
#           1587851143.9844875
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "ca8fa0f8260433fef4eac6579ef883fc",
#         "predicate_id": "RO:0002599",
#         "prr": 0.69191,
#         "publications": [],
#         "relation": [
#           "RO:0002599"
#         ],
#         "relation_label": [
#           "prevents"
#         ],
#         "ror": 0.69012,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0021146",
#         "type": "prevents",
#         "weight": 1
#       },
#       {
#         "case_count": 758,
#         "ctime": [
#           1587851143.9846506
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "a2178d4e628eefdc535e66edd7b15e52",
#         "predicate_id": "RO:0002599",
#         "prr": 0.87187,
#         "publications": [],
#         "relation": [
#           "RO:0002599"
#         ],
#         "relation_label": [
#           "prevents"
#         ],
#         "ror": 0.8712200000000001,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0003699",
#         "type": "prevents",
#         "weight": 1
#       },
#       {
#         "case_count": 936,
#         "ctime": [
#           1587851143.984433
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "97ba863e0634a258a7bd4f13f5c2154b",
#         "predicate_id": "RO:0002599",
#         "prr": 0.76794,
#         "publications": [],
#         "relation": [
#           "RO:0002599"
#         ],
#         "relation_label": [
#           "prevents"
#         ],
#         "ror": 0.76649,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0004900",
#         "type": "prevents",
#         "weight": 1
#       },
#       {
#         "case_count": 941,
#         "ctime": [
#           1587851143.9844065
#         ],
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "id": "286175077d57b4f311c121f3a29639c3",
#         "predicate_id": "RO:0002599",
#         "prr": 0.64252,
#         "publications": [],
#         "relation": [
#           "RO:0002599"
#         ],
#         "relation_label": [
#           "prevents"
#         ],
#         "ror": 0.64027,
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005379",
#         "type": "prevents",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1587851226.157031
#         ],
#         "edge_source": [
#           "mychem.get_drugcentral"
#         ],
#         "id": "c1ceb82427292fa60cd18f538af273b1",
#         "predicate_id": "biolink:contraindicated_for",
#         "publications": [],
#         "relation": [
#           "DrugCentral:0000001"
#         ],
#         "relation_label": [
#           "contraindication"
#         ],
#         "source_database": [
#           "mychem"
#         ],
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0001673",
#         "type": "contraindicated_for",
#         "weight": 1
#       },
#       {
#         "count": 1,
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "id": "c0daa6d354f8f344dff3c0dccf6863ed",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "relation": "in_clinical_trial_for",
#         "relation_label": "in_clinical_trial_for",
#         "source_database": "drugbank",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0100096",
#         "type": "in_clinical_trial_for",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592884173.117955,
#           1592973447.070259
#         ],
#         "edge_source": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 1.3129856984321078e-65,
#         "id": "2a2c20ef3a15a0dce005d5e8b1e22a1d",
#         "num_publications": 18.41552053065658,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH",
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to",
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0006502",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592973447.070135
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 5.914513174427336e-67,
#         "id": "a44804391705f164a5bb9c204716c92c",
#         "num_publications": 18.568955759052173,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0006502",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592884092.8484874,
#           1592971690.160379
#         ],
#         "edge_source": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 2.5e-323,
#         "id": "a32a6ee9ea3aa7d354cd1a77678d0e02",
#         "num_publications": 70.26593290481644,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH",
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to",
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0005249",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592971690.1602328
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 4.3989725225014235e-273,
#         "id": "8386cced5413d3602a1e4332437c341f",
#         "num_publications": 64.24939904904464,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0005249",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592980832.8028204
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 2.9144536752952735e-201,
#         "id": "e143a8681297e111bf172beccaa51605",
#         "num_publications": 27.60019664817587,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0005379",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592980832.802712
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 5.707133249646652e-201,
#         "id": "ad98da8d0cdb2b95e6ca0a652f40569a",
#         "num_publications": 27.528861054856034,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0005379",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592987618.7928975
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 2.530428493674143e-29,
#         "id": "c969c528d3617853bb34aa247ed9e95d",
#         "num_publications": 0.7145294629841605,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "CHEBI:15365",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "count": 3,
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "id": "37df1bf232ea833789b40a3153d8b555",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "relation": "in_clinical_trial_for",
#         "relation_label": "in_clinical_trial_for",
#         "source_database": "drugbank",
#         "source_id": "CHEBI:15365",
#         "target_id": "MONDO:0100096",
#         "type": "in_clinical_trial_for",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592884091.5928812,
#           1592974541.6855977
#         ],
#         "edge_source": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 7.71969765216213e-115,
#         "id": "1c48c41821627f5d739c2c5a487cf59c",
#         "num_publications": 38.651882832907766,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH",
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to",
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scibite_v5",
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0015137",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592974546.2627447
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 7.208700043189353e-21,
#         "id": "1959115ab28102902728ed814b1dc383",
#         "num_publications": 0.9974944478686665,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0015137",
#         "target_id": "CHEBI:4975",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592974541.685525
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 1.1321248092743078e-111,
#         "id": "4517e987116abb2e00576600b614b253",
#         "num_publications": 37.99496981792923,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0015137",
#         "target_id": "MONDO:0100096",
#         "type": "related_to",
#         "weight": 1
#       },
#       {
#         "ctime": [
#           1592983187.2642658
#         ],
#         "edge_source": [
#           "cord19_scigraph_v7"
#         ],
#         "enrichment_p": 1.3664049376447833e-119,
#         "id": "b8fd8b1f41940990aa64c864bbd11673",
#         "num_publications": 22.03710193419624,
#         "predicate_id": "owl:ObjectProperty",
#         "publications": [],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "relation_label": [
#           "related_to"
#         ],
#         "source_database": [
#           "cord19_scigraph_v7"
#         ],
#         "source_id": "MONDO:0004995",
#         "target_id": "MONDO:0100096",
# ...
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "643fdb270933cd61a955bdd179ad7c73",
#           "qg_id": "ab",
#           "weight": 0.9979473786958208
#         },
#         {
#           "kg_id": "c60a718be22bec610056f8783bd29243",
#           "qg_id": "ab",
#           "weight": 0.9975138775271195
#         },
#         {
#           "kg_id": "a36a8e13acb3df3e2fbaa557a64b85c7",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "d28135ab3f9c8ecb3bad81929bd68357",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "7439d7827535887b5a70c9c947bc6450",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "52d52d69-c177-4ee1-bc3e-30556cabe449",
#           "qg_id": "s13",
#           "weight": 8.314966379430189e-06
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "HP:0003326",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.12115397859072145
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "a32a6ee9ea3aa7d354cd1a77678d0e02",
#           "qg_id": "ab",
#           "weight": 1.0
#         },
#         {
#           "kg_id": "8386cced5413d3602a1e4332437c341f",
#           "qg_id": "ab",
#           "weight": 0.9999999999999996
#         },
#         {
#           "kg_id": "da825870d445b043d8c03cde137e1499",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "686485c7-1c29-45b6-8382-8f4b813f4f97",
#           "qg_id": "s19",
#           "weight": 0.0003834299723359802
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "MONDO:0005249",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.11829509471108407
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "91d70bc5d586a986d737b57b60f58470",
#           "qg_id": "ab",
#           "weight": 1.0
#         },
#         {
#           "kg_id": "c0daa6d354f8f344dff3c0dccf6863ed",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.11814602960478819
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "20efb5427532feca8c4414eec5dc08a7",
#           "qg_id": "ab",
#           "weight": 0.9999999999992633
#         },
#         {
#           "kg_id": "449ad2390a9c19c7160928c6a90c676e",
#           "qg_id": "ab",
#           "weight": 0.9999999999989644
#         },
#         {
#           "kg_id": "08fad98cd9189aca091f94ce1263db39",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "30c7096f-9c27-493c-8abd-82a74645d8a0",
#           "qg_id": "s21",
#           "weight": 0.0
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "HP:0012735",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.11814602960477583
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "8da08aa3cec388d5964a17c324bd9c33",
#           "qg_id": "ab",
#           "weight": 0.9999988488031701
#         },
#         {
#           "kg_id": "9b2d58d2499d827d194969160fd61854",
#           "qg_id": "ab",
#           "weight": 0.9999988262825834
#         },
#         {
#           "kg_id": "a2178d4e628eefdc535e66edd7b15e52",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "MONDO:0003699",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.11814601337863205
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "b8fd8b1f41940990aa64c864bbd11673",
#           "qg_id": "ab",
#           "weight": 0.9999936132029088
#         },
#         {
#           "kg_id": "3a2a0ef902c24176627a0fe0a4d8b08d",
#           "qg_id": "ab",
#           "weight": 0.9999946722219595
#         },
#         {
#           "kg_id": "84aa4a49db52be6a1be71060f32b219c",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "a209cac1-d831-4823-b873-ca643059f917",
#           "qg_id": "s9",
#           "weight": 0.0
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "MONDO:0004995",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.11814594784550932
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "2a2c20ef3a15a0dce005d5e8b1e22a1d",
#           "qg_id": "ab",
#           "weight": 0.9999533081482188
#         },
#         {
#           "kg_id": "a44804391705f164a5bb9c204716c92c",
#           "qg_id": "ab",
#           "weight": 0.9999570821148334
#         },
#         {
#           "kg_id": "26681dad7296fe33215922a961392821",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "MONDO:0006502",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.11814540417202275
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "6f1af85dfe9fca1dbd398d8eb7fd82ff",
#           "qg_id": "ab",
#           "weight": 0.9999097379714201
#         },
#         {
#           "kg_id": "21e0fb31f5500329d0e145e1a1c1d73e",
#           "qg_id": "ab",
#           "weight": 0.99991370285779
#         },
#         {
#           "kg_id": "a72584a4e86423d6d94314f0bce9ddc5",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "MONDO:0021113",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.11814479725964272
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "f9ae048208c0ca25ac0944ec49880d80",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "621c2897d9cd436ad9d0a0a5d1b7fd44",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "b507d7530765741a28afd91562ad49d1",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "f35918b9-c2eb-4192-b877-83ac3415f266",
#           "qg_id": "s36",
#           "weight": 5.283676206091492e-05
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "HP:0002098",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08932813820800495
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "7575a15c9db427fcff8a64e062782e7a",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "a0ab13c777e2d23b0ea6f82a2d06dd88",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "97ba863e0634a258a7bd4f13f5c2154b",
#           "qg_id": "bc",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "MONDO:0004900",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08931639747704095
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "4c4115b44968337424dd20dba4f70e0c",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "6495101038d3ebd2aef30675f0bef227",
#           "qg_id": "bc",
#           "weight": 0.4779289848884183
#         },
#         {
#           "kg_id": "85d83f0c-bb6b-422a-951b-a4b46b6d9b92",
#           "qg_id": "s56",
#           "weight": 0.00012210997097827914
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:29320",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08585345541462588
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "840140149eadac3be9345260d78fc8be",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "ebf691afed5e5d1f15efb4c068868544",
#           "qg_id": "bc",
#           "weight": 0.4776283954419569
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:135765",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08582617350793509
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "fdf8c945c14dbca6564f969ea567918e",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "6dfcdcf38aebae004be0134938b718f2",
#           "qg_id": "bc",
#           "weight": 0.46747458127322883
#         },
#         {
#           "kg_id": "b756d3ac-fdf9-4b15-9489-0b3b391bece5",
#           "qg_id": "s50",
#           "weight": 0.0009535233993085424
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:50275",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08522460758413297
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "37df1bf232ea833789b40a3153d8b555",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "c969c528d3617853bb34aa247ed9e95d",
#           "qg_id": "bc",
#           "weight": 0.43892684441131413
#         },
#         {
#           "kg_id": "f60f6390-3d4f-4a24-b455-5ce8ff5b3fe2",
#           "qg_id": "s54",
#           "weight": 0.0045732571755316975
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:15365",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08351648885065509
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "76398bba70a95e399d781a961c4fa06a",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "c625e04a5df86b5bb725f89028c741ff",
#           "qg_id": "bc",
#           "weight": 0.44068712947256294
#         },
#         {
#           "kg_id": "5aa6447f-12b2-4104-9476-db342554d6a0",
#           "qg_id": "s48",
#           "weight": 4.390150301292195e-06
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:8382",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08331650636606011
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "ea0ac9ce749f81122601bc5e874f74bc",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "3362f77d3da71d2a78c1fa2c2a377777",
#           "qg_id": "bc",
#           "weight": 0.4397435799825604
#         },
#         {
#           "kg_id": "b43c238f-94ff-4625-8abd-5cf6089517d7",
#           "qg_id": "s58",
#           "weight": 0.0006769336758347677
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:41879",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08329712574548896
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "421161f1bf8904ea7ee3e2133c21d58c",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "d8680bb5602b6b89d26a25b24e2c095b",
#           "qg_id": "bc",
#           "weight": 0.41980448462512765
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:91766",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08177802343110308
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "38463c3f2f4fa6107f8ed8e342e9c4b0",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "37894ba3dd3eb368addfaa8b2bdd3339",
#           "qg_id": "bc",
#           "weight": 0.40845165563794494
#         },
#         {
#           "kg_id": "5b2a7115-51be-473e-a53f-88e477082f0d",
#           "qg_id": "s44",
#           "weight": 0.002129237798704775
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:2676",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08106848989849964
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "0bec65fb831ddbedf776323dd197cc05",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "e45b6937a7ccfd5efc48a7f46df2103a",
#           "qg_id": "bc",
#           "weight": 0.41010208546283833
#         },
#         {
#           "kg_id": "d846a7fb-e2f8-4a1c-8163-6e3d2ec06202",
#           "qg_id": "s52",
#           "weight": 0.0
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:17650",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.08103113009048245
#     },
#     {
#       "edge_bindings": [
#         {
#           "kg_id": "8334c5cbc77f948b76c66df621baa667",
#           "qg_id": "ab",
#           "weight": 0.2679491924311228
#         },
#         {
#           "kg_id": "11a0002c5b1939093e85a34dd17eec0d",
#           "qg_id": "bc",
#           "weight": 0.396633700107472
#         },
#         {
#           "kg_id": "a86600ad-0b26-49a7-888c-db2eacba6526",
#           "qg_id": "s40",
#           "weight": 0.00023048937941405612
#         }
#       ],
#       "node_bindings": [
#         {
#           "kg_id": "MONDO:0100096",
#           "qg_id": "a"
#         },
#         {
#           "kg_id": "CHEBI:16899",
#           "qg_id": "b"
#         },
#         {
#           "kg_id": "CHEBI:4975",
#           "qg_id": "c"
#         }
#       ],
#       "score": 0.07997690928772402
#     }
#   ]
# }

# %%
with open('famcov.json','w') as outf:
    json.dump(robokop_result,outf,indent=2)

# %% [markdown]
# ## Coalesce Answers by Property

# %%
url = 'https://answercoalesce.renci.org/coalesce'
params = {'method':'property'}
p_r = requests.post(url,json=robokop_result,params=params)
print(p_r.status_code)
property_result = p_r.json()
# Out:
# 200

# %%
property_result['results']
# Out:
# []

# %%
results = property_result['results']
num_grouped=[]
p_values=[]
properties=[]
for result in results:
    chemnode = result['node_bindings'][2]
    for p,prop in zip(chemnode['p_values'],chemnode['properties']):
        num_grouped.append(len(chemnode['kg_id']))
        p_values.append(p)
        properties.append(prop)
df = pd.DataFrame( {'NumberGrouped': num_grouped, 'p_value':p_values, 'PropertyGroup':properties})
df.sort_values(by='p_value',inplace=True)
df
# Out:
# Empty DataFrame
# Columns: [NumberGrouped, p_value, PropertyGroup]
# Index: []

# %% [markdown]
# ## Coalesce Answers by Ontology

# %%
url = 'https://answercoalesce.renci.org/coalesce'
params = {'method':'ontology'}
o_r = requests.post(url,json=robokop_result,params=params)
print(o_r.status_code)
ontology_result = o_r.json()
print( len(ontology_result['results']))
# Out:
# 200
# 18

# %%
results = ontology_result['results']
for result in results:
    print('\n================')
    chemnode = result['node_bindings'][1]
    sclass = chemnode['superclass']
    label = getlabel(sclass)
    nodes = chemnode['kg_id']
    labels = {x: f'{getlabel(x)}' for x in nodes }
    for x in nodes:
        print(f'{labels[x]} ({x})')
    print('----have superclass----')
    print(f'{label} ({sclass})')
# Out:
# ================
# respiratory failure (MONDO:0021113)
# acute respiratory distress syndrome (MONDO:0006502)
# ----have superclass----
# respiratory failure (MONDO:0021113)
#
# ================
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# glucocorticoid (CHEBI:24261)
#
# ================
# methylprednisolone succinate (CHEBI:135765)
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# corticosteroid hormone (CHEBI:36699)
#
# ================
# respiratory failure (MONDO:0021113)
# acute respiratory distress syndrome (MONDO:0006502)
# ----have superclass----
# respiratory failure (MONDO:0021113)
#
# ================
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# glucocorticoid (CHEBI:24261)
#
# ================
# methylprednisolone succinate (CHEBI:135765)
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# corticosteroid hormone (CHEBI:36699)
#
# ================
# respiratory failure (MONDO:0021113)
# acute respiratory distress syndrome (MONDO:0006502)
# ----have superclass----
# respiratory failure (MONDO:0021113)
#
# ================
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# glucocorticoid (CHEBI:24261)
#
# ================
# methylprednisolone succinate (CHEBI:135765)
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# corticosteroid hormone (CHEBI:36699)
#
# ================
# respiratory failure (MONDO:0021113)
# acute respiratory distress syndrome (MONDO:0006502)
# ----have superclass----
# respiratory failure (MONDO:0021113)
#
# ================
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# glucocorticoid (CHEBI:24261)
#
# ================
# methylprednisolone succinate (CHEBI:135765)
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# corticosteroid hormone (CHEBI:36699)
#
# ================
# respiratory failure (MONDO:0021113)
# acute respiratory distress syndrome (MONDO:0006502)
# ----have superclass----
# respiratory failure (MONDO:0021113)
#
# ================
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# glucocorticoid (CHEBI:24261)
#
# ================
# methylprednisolone succinate (CHEBI:135765)
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# corticosteroid hormone (CHEBI:36699)
#
# ================
# respiratory failure (MONDO:0021113)
# acute respiratory distress syndrome (MONDO:0006502)
# ----have superclass----
# respiratory failure (MONDO:0021113)
#
# ================
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# glucocorticoid (CHEBI:24261)
#
# ================
# methylprednisolone succinate (CHEBI:135765)
# dexamethasone (CHEBI:41879)
# prednisone (CHEBI:8382)
# cortisol (CHEBI:17650)
# ----have superclass----
# corticosteroid hormone (CHEBI:36699)

# %%
from copy import deepcopy
onrd = deepcopy(ontology_result)
for n in onrd['query_graph']['nodes']:
    if 'curie' in n and n['curie'] is None:
        del[n['curie']]
for n in onrd['knowledge_graph']['nodes']:
    if 'name' not in n:
        label = getlabel(n['id'])
        n['name'] = label
for e in onrd['knowledge_graph']['edges']:
    e['id'] = str(e['id'])
for r in onrd['results']:
    for eb in r['edge_bindings']:
        eb['kg_id'] = [ str(x) for x in eb['kg_id']]
react_component = GammaViewer(props={"data":onrd})
display(react_component)

# %% [markdown]
# ## Coalescence by Graph

# %% [markdown]
# Coalescence by graph is similar to coalescence by ontology, but the new relationships can be more general than `is_a`.

# %%
url = 'https://answercoalesce.renci.org/coalesce'
params = {'method':'graph'}
g_r = requests.post(url,json=robokop_result,params=params)
print(g_r.status_code)
graph_result = g_r.json()
print( len(graph_result['results']))

# %%
from copy import deepcopy
gd = deepcopy(graph_result)
for n in gd['query_graph']['nodes']:
    if 'curie' in n and n['curie'] is None:
        del[n['curie']]
for n in gd['knowledge_graph']['nodes']:
    if 'name' not in n:
        label = getlabel(n['id'])
        n['name'] = label
for e in gd['knowledge_graph']['edges']:
    e['id'] = str(e['id'])
for r in gd['results']:
    for eb in r['edge_bindings']:
        eb['kg_id'] = [ str(x) for x in eb['kg_id']]
react_component = GammaViewer(props={"data":gd})
display(react_component)

# %%
def draw_one(results,rnum):
    g = deepcopy(results)
    g['results']=[g['results'][rnum]]
    kgs = set()
    for nb in g['results'][0]['node_bindings']:
        for kgid in nb['kg_id']:
            kgs.add(kgid)
    kg = g['knowledge_graph']
    kg['nodes'] = [n for n in kg['nodes'] if n['id'] in kgs ]
    kg['edges'] = [e for e in kg['edges'] if (e['source_id'] in kgs) and (e['target_id'] in kgs)]
    react_component = GammaViewer(props={"data":g})
    display(react_component)

# %%
draw_one(gd,3)
