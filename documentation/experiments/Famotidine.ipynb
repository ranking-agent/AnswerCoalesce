# %% [markdown]
# # Famotidine Covid
#
# This is a test case to see whether Answer Merging helps with the arbitrary query problem. The problem is: I want to know the most interesting way in which these two entities are related.  What is it?  One option is to do question rewriting.  But another (this one) is to general queries and then work on merging them.

# %%
import requests
import json
import time
import pandas as pd

#GammaViewer available from https://github.com/ranking-agent/gamma-viewer
#from GammaViewer import GammaViewer
from IPython.display import display

# %%
def getlabel(curie):
    url = 'https://nodenormalization-sri.renci.org/get_normalized_nodes'
    try:
        r = requests.get(url,params={'curie':curie}).json()
        return r[curie]['id']['label']
    except:
        return ''

class RobokopMessenger:
    def __init__(self):
        self.url = 'https://covidkop.renci.org/messenger'
    def pipeline(self,request,full = True):
        #normalize question
        purl = f'{self.url}/normalize'
        print(purl)
        response = requests.post( purl , json=request )
        normalized = response.json()
        
        #answer question
        request = { 'message': normalized, }
        response = requests.post( f'{self.url}/answer', json=request )
        answered = response.json()

        if not full:
            return answered
        
        #Yank
        #request = { 'message': answered, }
        #response = requests.post( f'{self.url}/yank', json=request )
        #filled = response.json()
        
        #support
        request = { 'message': answered, }
        response = requests.post( 'http://robokop.renci.org:4868/support', json=request )
        supported = response.json()
        #weight
        request = { 'message': supported, }
        response = requests.post( 'http://robokop.renci.org:4868/weight_correctness', json=request )
        weighted = response.json()
        #score
        request = { 'message': weighted, }
        response = requests.post( 'http://robokop.renci.org:4868/score', json=request )
        scored = response.json()

        # remove all elements that dont have data
        for element in scored['query_graph']['nodes']:
            for key in [key for key in element if element[key] is None]:del element[key]

        return scored

    
robokop=RobokopMessenger()

# %%
def create_message():
    query_graph = {
    "nodes": [
        {
            #Covid-19
            "id": "a",
            "type": "disease",
            "curie": "MONDO:0100096"
        },
        {
            "id": "b",
            "type": "named_thing"
        },
        {
            #Famotidine
            "id": "c",
            "type": "chemical_substance",
            "curie": "CHEBI:4975"
        }
    ],
    "edges": [
        {
            "id": "ab",
            "source_id": "a",
            "target_id": "b"
        },
        {
            "id": "bc",
            "source_id": "c",
            "target_id": "b"
        }
    ]
    }
    message = {"message": {"query_graph": query_graph,
                           'results':[{"node_bindings": [],"edge_bindings": []}]}}
    return message

# %%
message = create_message()
#react_component = GammaViewer(props={"data":message['message']})
#display(react_component)

# %%
robokop_result = robokop.pipeline(message,full=True)
print( json.dumps(robokop_result,indent=2))
# Out:
# https://covidkop.renci.org/messenger/normalize
# {
#   "query_graph": {
#     "nodes": [
#       {
#         "id": "a",
#         "curie": [
#           "MONDO:0100096"
#         ],
#         "type": "disease"
#       },
#       {
#         "id": "b",
#         "type": "named_thing"
#       },
#       {
#         "id": "c",
#         "curie": [
#           "CHEBI:4975"
#         ],
#         "type": "chemical_substance"
#       }
#     ],
#     "edges": [
#       {
#         "id": "ab",
#         "source_id": "a",
#         "target_id": "b",
#         "type": null
#       },
#       {
#         "id": "bc",
#         "source_id": "c",
#         "target_id": "b",
#         "type": null
#       }
#     ]
#   },
#   "knowledge_graph": {
#     "nodes": [
#       {
#         "id": "MONDO:0100096",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "SNOMEDCT:840539006",
#           "MONDO:0100096",
#           "DOID:0080600"
#         ],
#         "omnicorp_article_count": 0,
#         "synonyms": [],
#         "name": "COVID-19"
#       },
#       {
#         "id": "NCBITaxon:2697049",
#         "type": [
#           "named_thing",
#           "ontology_class",
#           "organism_taxon"
#         ],
#         "equivalent_identifiers": [
#           "NCBITaxon:2697049",
#           "MESH:C000656484"
#         ],
#         "omnicorp_article_count": 0,
#         "name": "Severe acute respiratory syndrome coronavirus 2"
#       },
#       {
#         "id": "CHEBI:4975",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "chemical_substance",
#           "molecular_entity"
#         ],
#         "antagonist": true,
#         "anti_ulcer_drug": true,
#         "oral": true,
#         "synonyms": [
#           "N'-(aminosulfonyl)-3-[({2-[(diaminomethylidene)amino]-1,3-thiazol-4-yl}methyl)sulfanyl]propanimidamide",
#           "(1-Amino-3-(((2-((diaminomethylene)amino)-4-thiazolyl)methyl)thio)propylidene)sulfamide",
#           "3-(((2-((Aminoiminomethyl)amino)-4-thiazolyl)methyl)thio)-N-(aminosulfonyl)propanimidamide",
#           "3-(((2-((Diaminomethylene)amino)-4-thiazolyl)methyl)thio)-N(sup 2)-sulfamoylpropionamidine",
#           "famotidina",
#           "famotidine",
#           "famotidinum",
#           "N-Sulfamoyl-3-((2-guanidinothiazol-4-yl)methylthio)propionamide",
#           "Pepcid"
#         ],
#         "pharmacological_role": true,
#         "biochemical_role": true,
#         "biological_role": true,
#         "pharmaceutical": true,
#         "therapeutic_flag": true,
#         "application": true,
#         "topical": false,
#         "drugbank.accession_number": "APRD00296",
#         "drug": true,
#         "drugbank.categories": [
#           "Acid Reducers",
#           "Alimentary Tract and Metabolism",
#           "Anti-Ulcer Agents",
#           "Drugs for Acid Related Disorders",
#           "Drugs for Peptic Ulcer and Gastro-Oesophageal Reflux Disease (Gord)",
#           "Gastric Acid Lowering Agents",
#           "Gastrointestinal Agents",
#           "Histamine Agents",
#           "Histamine Antagonists",
#           "Histamine H2 Antagonists",
#           "Neurotransmitter Agents",
#           "OAT3/SLC22A8 Inhibitors",
#           "OAT3/SLC22A8 Substrates",
#           "OCT2 Inhibitors",
#           "Potential QTc-Prolonging Agents",
#           "QTc Prolonging Agents",
#           "Sulfur Compounds",
#           "Thiazoles"
#         ],
#         "molecule_properties": "{'alogp': '-0.77', 'aromatic_rings': 1, 'cx_logd': '-2.67', 'cx_logp': '-1.95', 'cx_most_apka': '9.29', 'cx_most_bpka': '8.38', 'full_molformula': 'C8H15N7O2S3', 'full_mwt': '337.46', 'hba': 6, 'hba_lipinski': 9, 'hbd': 4, 'hbd_lipinski': 8, 'heavy_atoms': 20, 'molecular_species': 'NEUTRAL', 'mw_freebase': '337.46', 'mw_monoisotopic': '337.0449', 'num_lipinski_ro5_violations': 1, 'num_ro5_violations': 0, 'psa': '175.83', 'qed_weighted': '0.29', 'ro3_pass': 'N', 'rtb': 7}",
#         "withdrawn_flag": false,
#         "P450_inhibitor": true,
#         "parenteral": true,
#         "role": true,
#         "histamine_antagonist": true,
#         "natural_product": 1,
#         "EC_1.14.*_(oxidoreductase_acting_on_paired_donors__with_incorporation_or_reduction_of_molecular_oxygen)_inhibitor": true,
#         "prodrug": 0,
#         "EC_1.*_(oxidoreductase)_inhibitor": true,
#         "H2_receptor_antagonist": true,
#         "EC_1.14.14.*_(oxidoreductase_acting_on_paired_donors__incorporating_of_1_atom_of_oxygen__with_reduced_flavin_or_flavoprotein_as_one_donor)_inhibitor": true,
#         "name": "famotidine",
#         "inhibitor": true,
#         "equivalent_identifiers": [
#           "PUBCHEM.COMPOUND:5353622",
#           "INCHIKEY:NJTQENWDJVHUOX-GXDHUFHOSA-N",
#           "UNII:5QZO15J2Z8",
#           "MESH:D015738",
#           "gtpo:7074",
#           "PUBCHEM.COMPOUND:5702160",
#           "DRUGBANK:DB00927",
#           "PUBCHEM.COMPOUND:3325",
#           "CHEMBL.COMPOUND:CHEMBL902",
#           "CHEBI:4975",
#           "HMDB:HMDB0001919"
#         ],
#         "omnicorp_article_count": 2181,
#         "neurotransmitter_agent": true,
#         "EC_1.14.14.1_(unspecific_monooxygenase)_inhibitor": true,
#         "enzyme_inhibitor": true,
#         "drugbank.approved": true,
#         "molecule_type": "Small molecule",
#         "histaminergic_drug": true
#       },
#       {
#         "id": "MONDO:0056821",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "SNOMEDCT:68409003",
#           "MONDO:0056821",
#           "UMLS:C2747929",
#           "UMLS:C0264383",
#           "MEDDRA:10067472"
#         ],
#         "omnicorp_article_count": 1404,
#         "synonyms": [
#           "organized pneumonia",
#           "BOOP",
#           "constrictive bronchiolitis",
#           "organizing pneumonia"
#         ],
#         "name": "bronchiolitis obliterans organizing pneumonia"
#       },
#       {
#         "id": "MONDO:0019737",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C2717961",
#           "MESH:D057049",
#           "SNOMEDCT:126729006",
#           "MONDO:0019737",
#           "ORPHANET:93573",
#           "MEDDRA:10043645",
#           "NCIT:C62605"
#         ],
#         "omnicorp_article_count": 3086,
#         "synonyms": [],
#         "name": "thrombotic microangiopathy"
#       },
#       {
#         "id": "MONDO:0015796",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "MEDDRA:10069351",
#           "NCIT:C155766",
#           "SNOMEDCT:315345002",
#           "EFO:0004610",
#           "MESH:D055371",
#           "UMLS:C0242488",
#           "ORPHANET:178320",
#           "MONDO:0015796"
#         ],
#         "omnicorp_article_count": 12502,
#         "synonyms": [],
#         "name": "acute lung injury"
#       },
#       {
#         "id": "NCBIGene:7124",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "molecular_entity",
#           "gene",
#           "gene_or_gene_product",
#           "macromolecular_machine",
#           "genomic_entity"
#         ],
#         "equivalent_identifiers": [
#           "HGNC:11892",
#           "NCBIGene:7124",
#           "UniProtKB:P01375",
#           "NCBIGene:7124",
#           "ENSEMBL:ENSG00000232810"
#         ],
#         "location": "6p21.33",
#         "gene_family_id": [
#           781
#         ],
#         "omnicorp_article_count": 0,
#         "name": "TNF",
#         "taxon": 9606,
#         "synonyms": [],
#         "start_position": 31575565,
#         "chromosome": "6",
#         "ensembl_name": "TNF",
#         "locus_group": "protein-coding gene",
#         "description": "tumor necrosis factor [Source:HGNC Symbol;Acc:HGNC:11892]",
#         "gene_biotype": "protein_coding",
#         "gene_family": [
#           "Tumor necrosis factor superfamily"
#         ],
#         "end_position": 31578336
#       },
#       {
#         "id": "MONDO:0005478",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "MONDO:0005478",
#           "MESH:D016171",
#           "MEDDRA:10044066",
#           "UMLS:C1328584",
#           "HP:0001664",
#           "NCIT:C50779",
#           "SNOMEDCT:31722008",
#           "UMLS:C0040479"
#         ],
#         "omnicorp_article_count": 4291,
#         "synonyms": [],
#         "name": "torsades de pointes"
#       },
#       {
#         "id": "MONDO:0004652",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "MESH:D018410",
#           "EFO:1001272",
#           "DOID:874",
#           "UMLS:C2189270",
#           "UMLS:C4727977",
#           "MEDDRA:10060946",
#           "SNOMEDCT:53084003",
#           "UMLS:C0375327",
#           "NCIT:C26704",
#           "UMLS:C4727975",
#           "UMLS:C0004626",
#           "MONDO:0004652",
#           "UMLS:C4727976"
#         ],
#         "omnicorp_article_count": 3605,
#         "synonyms": [],
#         "name": "bacterial pneumonia"
#       },
#       {
#         "id": "MONDO:0002258",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "MEDDRA:10043521",
#           "SNOMEDCT:405737000",
#           "UMLS:C0031350",
#           "SNOMEDCT:162400007",
#           "UMLS:C3854543",
#           "UMLS:C0858940",
#           "SNOMEDCT:284207003",
#           "UMLS:C0242429",
#           "UMLS:C0241381",
#           "UMLS:C0863112",
#           "UMLS:C0858941",
#           "MONDO:0002258",
#           "UMLS:C4087337",
#           "UMLS:C2363731",
#           "UMLS:C0542075",
#           "SNOMEDCT:162397003",
#           "UMLS:C0562057",
#           "UMLS:C3854544",
#           "DOID:2275",
#           "UMLS:C0858938",
#           "MESH:D010612",
#           "MEDDRA:10068319",
#           "NCIT:C50747",
#           "UMLS:C0700184",
#           "NCIT:C26851"
#         ],
#         "omnicorp_article_count": 12474,
#         "synonyms": [],
#         "name": "pharyngitis"
#       },
#       {
#         "id": "MONDO:0001208",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "acute_disease": true,
#         "equivalent_identifiers": [
#           "UMLS:C4285915",
#           "SNOMEDCT:65710008",
#           "MEDDRA:10001053",
#           "UMLS:C0748352",
#           "MONDO:0001208",
#           "NCIT:C27043",
#           "SNOMEDCT:67905004",
#           "UMLS:C0865850",
#           "UMLS:C0264490",
#           "UMLS:C0264491"
#         ],
#         "omnicorp_article_count": 5931,
#         "synonyms": [
#           "acute respiratory failure",
#           "respiratory failure, acute"
#         ],
#         "name": "acute respiratory failure"
#       },
#       {
#         "id": "MONDO:0045057",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "NCIT:C121627",
#           "UMLS:C3203501",
#           "UMLS:C0683369",
#           "SNOMEDCT:40917007",
#           "SNOMEDCT:112077003",
#           "NCIT:C37928",
#           "SNOMEDCT:231440006",
#           "MESH:D003221",
#           "UMLS:C0813178",
#           "UMLS:C3203503",
#           "UMLS:C0857386",
#           "UMLS:C0338642",
#           "UMLS:C1306588",
#           "UMLS:C0751054",
#           "SNOMEDCT:191492000",
#           "MEDDRA:10012219",
#           "UMLS:C0858855",
#           "UMLS:C0154596",
#           "UMLS:C0152124",
#           "UMLS:C0154333",
#           "MEDDRA:10010305",
#           "UMLS:C0422893",
#           "MEDDRA:10013395",
#           "EFO:0009267",
#           "SNOMEDCT:2776000",
#           "NCIT:C92639",
#           "UMLS:C0860621",
#           "SNOMEDCT:231439009",
#           "UMLS:C0029221",
#           "UMLS:C0235071",
#           "UMLS:C0011206",
#           "MEDDRA:10012373",
#           "NCIT:C78253",
#           "MESH:D003244",
#           "UMLS:C0549249",
#           "SNOMEDCT:40673001",
#           "NCIT:C2981",
#           "UMLS:C0234983",
#           "UMLS:C0542207",
#           "UMLS:C0233407",
#           "SNOMEDCT:191678001",
#           "NCIT:C34868",
#           "UMLS:C0751053",
#           "UMLS:C0860623",
#           "UMLS:C0009792",
#           "UMLS:C1142436",
#           "UMLS:C0041862",
#           "UMLS:C0338644",
#           "UMLS:C0860622",
#           "SNOMEDCT:286933003",
#           "UMLS:C0858851",
#           "UMLS:C0859069",
#           "UMLS:C0235070",
#           "SNOMEDCT:62476001",
#           "UMLS:C0541890",
#           "UMLS:C1142529",
#           "MESH:D003693",
#           "MEDDRA:10031077",
#           "UMLS:C0856071",
#           "UMLS:C0877609",
#           "UMLS:C0751055",
#           "UMLS:C0338664",
#           "UMLS:C0009676",
#           "SNOMEDCT:609585002",
#           "MEDDRA:10012218",
#           "UMLS:C0154326",
#           "HP:0001289",
#           "UMLS:C0877450",
#           "UMLS:C1285577",
#           "UMLS:C1737242",
#           "UMLS:C3203502",
#           "UMLS:C0857152",
#           "UMLS:C0857042",
#           "UMLS:C4285867",
#           "MONDO:0045057"
#         ],
#         "omnicorp_article_count": 13344,
#         "psychiatric_disorder": true,
#         "synonyms": [
#           "organic brain syndrome"
#         ],
#         "name": "delirium"
#       },
#       {
#         "id": "MONDO:0005249",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "SNOMEDCT:233604007",
#           "UMLS:C3714636",
#           "MONDO:0005249",
#           "HP:0002090",
#           "MESH:D011014",
#           "UMLS:C0887898",
#           "UMLS:C2074898",
#           "UMLS:C0032285",
#           "NCIT:C3333",
#           "EFO:0003106",
#           "MEDDRA:10035742",
#           "DOID:552"
#         ],
#         "omnicorp_article_count": 94661,
#         "synonyms": [],
#         "name": "pneumonia"
#       },
#       {
#         "id": "MONDO:0003785",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "MESH:D007970",
#           "UMLS:C0023530",
#           "MEDDRA:10024384",
#           "DOID:615",
#           "MONDO:0003785",
#           "HP:0001882",
#           "EFO:0004233",
#           "NCIT:C26816",
#           "SNOMEDCT:84828003"
#         ],
#         "omnicorp_article_count": 19821,
#         "synonyms": [],
#         "name": "leukopenia"
#       },
#       {
#         "id": "MONDO:0005252",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C1959583",
#           "UMLS:CN236639",
#           "MONDO:0005252",
#           "UMLS:C1961112",
#           "MESH:D006333",
#           "SNOMEDCT:84114007",
#           "NCIT:C50577"
#         ],
#         "omnicorp_article_count": 157881,
#         "synonyms": [
#           "cardiac failure",
#           "cardiac insufficiency",
#           "failure, heart",
#           "heart failure",
#           "insufficiency, Cardiac"
#         ],
#         "name": "heart failure"
#       },
#       {
#         "id": "MONDO:0024355",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "SNOMEDCT:54150009",
#           "UMLS:C0863094",
#           "MONDO:0024355",
#           "UMLS:C0035243",
#           "UMLS:C0041912",
#           "UMLS:C4759838",
#           "MEDDRA:10024970",
#           "MEDDRA:10062352",
#           "UMLS:C3544325",
#           "MESH:D012141",
#           "SNOMEDCT:275498002",
#           "MEDDRA:10046306",
#           "HP:0011947"
#         ],
#         "omnicorp_article_count": 6753,
#         "synonyms": [],
#         "name": "respiratory tract infectious disease"
#       },
#       {
#         "id": "MONDO:0001673",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "MESH:D003967",
#           "DOID:13250",
#           "UMLS:C1290807",
#           "NCIT:C2987",
#           "UMLS:C0011991",
#           "SNOMEDCT:267060006",
#           "HP:0002014",
#           "SNOMEDCT:62315008",
#           "MONDO:0001673",
#           "SNOMEDCT:128333008"
#         ],
#         "omnicorp_article_count": 98281,
#         "synonyms": [
#           "diarrhea",
#           "diarrheal disease",
#           "diarrheal disorder",
#           "diarrhoea",
#           "frequent stools",
#           "loose stools",
#           "diarrhea of presumed infectious origin"
#         ],
#         "name": "diarrheal disease"
#       },
#       {
#         "id": "MONDO:0001243",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "NCIT:C2992",
#           "MONDO:0001243",
#           "MESH:D004211",
#           "SNOMEDCT:67406007",
#           "DOID:11247",
#           "UMLS:C0860217",
#           "MEDDRA:10013442",
#           "NCIT:C131658",
#           "UMLS:C1868936",
#           "HP:0005521",
#           "UMLS:C4321305",
#           "UMLS:C0012739"
#         ],
#         "omnicorp_article_count": 18147,
#         "synonyms": [],
#         "name": "disseminated intravascular coagulation"
#       },
#       {
#         "id": "MONDO:0021146",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C0744648",
#           "SNOMEDCT:230461009",
#           "UMLS:C0948396",
#           "UMLS:C1328569",
#           "NCIT:C34661",
#           "SNOMEDCT:162308004",
#           "SNOMEDCT:162299003",
#           "SNOMEDCT:712831003",
#           "HP:0002315",
#           "UMLS:C0751190",
#           "UMLS:C0239888",
#           "UMLS:C0876980",
#           "UMLS:C4285864",
#           "EFO:0009550",
#           "UMLS:C1168188",
#           "UMLS:C0393735",
#           "UMLS:C0239886",
#           "MESH:D020773",
#           "UMLS:C0858898",
#           "MESH:D006261",
#           "SNOMEDCT:712826000",
#           "UMLS:C0751187",
#           "UMLS:C0857361",
#           "UMLS:C0423622",
#           "UMLS:C0423623",
#           "UMLS:C0474366",
#           "UMLS:C0857492",
#           "SNOMEDCT:162304002",
#           "UMLS:C0751192",
#           "UMLS:C0423621",
#           "UMLS:C0239885",
#           "MONDO:0021146",
#           "UMLS:C0018681",
#           "MEDDRA:10019211",
#           "SNOMEDCT:267096005",
#           "MEDDRA:10019231",
#           "MEDDRA:10060854",
#           "SNOMEDCT:445511002",
#           "UMLS:C0151293",
#           "UMLS:C0751189",
#           "UMLS:C0752149",
#           "UMLS:C1868934",
#           "SNOMEDCT:41413006",
#           "UMLS:C0856864",
#           "UMLS:C0751186",
#           "SNOMEDCT:86925001",
#           "SNOMEDCT:25064002",
#           "SNOMEDCT:162301005",
#           "UMLS:C0231613",
#           "UMLS:C0857471",
#           "UMLS:C0877781",
#           "SNOMEDCT:330007",
#           "UMLS:C1262010",
#           "UMLS:C0423618",
#           "UMLS:C0028838",
#           "SNOMEDCT:458241000124102",
#           "UMLS:C0858248",
#           "UMLS:C0752147"
#         ],
#         "omnicorp_article_count": 4917,
#         "synonyms": [
#           "headache disorder",
#           "cephalgia syndrome",
#           "cephalgia syndromes",
#           "chronic daily headache",
#           "chronic daily headaches",
#           "chronic headache",
#           "chronic headaches",
#           "daily headache, chronic",
#           "daily headaches, chronic",
#           "headache syndrome",
#           "headache syndromes",
#           "headache, chronic",
#           "headache, chronic daily",
#           "headache, intractable",
#           "headaches, chronic",
#           "headaches, chronic daily",
#           "headaches, intractable",
#           "intractable headache",
#           "intractable headaches",
#           "syndrome, headache"
#         ],
#         "name": "headache disorder"
#       },
#       {
#         "id": "MONDO:0005265",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C0021390",
#           "MONDO:0005265",
#           "SNOMEDCT:302168000",
#           "MESH:D015212",
#           "NCIT:C3138",
#           "SNOMEDCT:24526004",
#           "HP:0002037",
#           "UMLS:C0578878",
#           "DOID:0050589",
#           "MEDDRA:10021972",
#           "EFO:0003767"
#         ],
#         "omnicorp_article_count": 46420,
#         "synonyms": [],
#         "name": "inflammatory bowel disease"
#       },
#       {
#         "id": "MONDO:0004995",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C0859057",
#           "MONDO:0004995",
#           "MEDDRA:10007649",
#           "DOID:1287",
#           "UMLS:C0728936",
#           "SNOMEDCT:49601007",
#           "UMLS:C0007222",
#           "NCIT:C2931",
#           "MESH:D002318",
#           "UMLS:C0243050",
#           "HP:0001626",
#           "UMLS:C0549406",
#           "UMLS:C0859056",
#           "MESH:D018376"
#         ],
#         "omnicorp_article_count": 226519,
#         "synonyms": [],
#         "name": "cardiovascular disease"
#       },
#       {
#         "id": "MONDO:0019810",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "MONDO:0019810",
#           "SNOMEDCT:768962006",
#           "ORPHANET:95455",
#           "UMLS:C0014518",
#           "UMLS:C0858685",
#           "EFO:0004775",
#           "NCIT:C79777",
#           "SNOMEDCT:23067006",
#           "MEDDRA:10044223",
#           "UMLS:C0151626",
#           "MESH:D004816"
#         ],
#         "omnicorp_article_count": 277908,
#         "synonyms": [],
#         "name": "toxic epidermal necrolysis"
#       },
#       {
#         "id": "MONDO:0005113",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C0858746",
#           "DOID:104",
#           "UMLS:C1096600",
#           "UMLS:C1096747",
#           "SNOMEDCT:87628006",
#           "UMLS:C0085423",
#           "MESH:D001424",
#           "EFO:0000771",
#           "UMLS:C1096601",
#           "NCIT:C2890",
#           "MEDDRA:10060945",
#           "UMLS:C0004623",
#           "MONDO:0005113"
#         ],
#         "omnicorp_article_count": 95023,
#         "synonyms": [],
#         "name": "bacterial infectious disease"
#       },
#       {
#         "id": "MONDO:0005263",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C0856923",
#           "MONDO:0005263",
#           "UMLS:C0041696",
#           "MEDDRA:10012378",
#           "UMLS:C0541868",
#           "UMLS:C0541869",
#           "UMLS:C0154437",
#           "UMLS:C1386135",
#           "SNOMEDCT:192080009",
#           "HP:0000716",
#           "MEDDRA:10012401",
#           "NCIT:C35094",
#           "UMLS:C0581391",
#           "UMLS:C0859997",
#           "SNOMEDCT:712823008",
#           "UMLS:C0011581",
#           "UMLS:C0011570",
#           "UMLS:C1868899",
#           "SNOMEDCT:21061000119107",
#           "UMLS:C0349218",
#           "UMLS:C0235876"
#         ],
#         "omnicorp_article_count": 40610,
#         "psychiatric_disorder": true,
#         "synonyms": [],
#         "name": "unipolar depression"
#       },
#       {
#         "id": "MONDO:0006932",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "acute_disease": true,
#         "equivalent_identifiers": [
#           "DOID:11396",
#           "UMLS:C0034063",
#           "NCIT:C26868",
#           "EFO:1001134",
#           "UMLS:C1736185",
#           "MEDDRA:10037424",
#           "MONDO:0006932",
#           "UMLS:C0856142",
#           "UMLS:C0748123",
#           "HP:0100598",
#           "MESH:D011654",
#           "UMLS:C2939069",
#           "MEDDRA:10037423",
#           "SNOMEDCT:19242006"
#         ],
#         "omnicorp_article_count": 21499,
#         "synonyms": [],
#         "name": "pulmonary edema"
#       },
#       {
#         "id": "MONDO:0015137",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "SNOMEDCT:386661006",
#           "SNOMEDCT:50177009",
#           "UMLS:C0860192",
#           "UMLS:C0015967",
#           "UMLS:C1709787",
#           "SNOMEDCT:704425001",
#           "ORPHANET:101995",
#           "MESH:D005334",
#           "UMLS:C0743842",
#           "NCIT:C35292",
#           "UMLS:C0743971",
#           "UMLS:C2830450",
#           "UMLS:C0856281",
#           "MESH:D005335",
#           "SNOMEDCT:102496004",
#           "UMLS:C0858754",
#           "NCIT:C118240",
#           "HP:0011134",
#           "NCIT:C34608",
#           "MONDO:0015137",
#           "UMLS:C4324354",
#           "SNOMEDCT:7520000",
#           "SNOMEDCT:274640006",
#           "MEDDRA:10037660",
#           "UMLS:C3889979",
#           "NCIT:C50720",
#           "UMLS:C1096446",
#           "MEDDRA:10034533",
#           "HP:0001945",
#           "UMLS:C0235723",
#           "UMLS:C0424781",
#           "UMLS:C0015974",
#           "NCIT:C26921",
#           "UMLS:C0015970",
#           "UMLS:C0239574",
#           "NCIT:C3038",
#           "UMLS:C1397229",
#           "SNOMEDCT:304213008",
#           "UMLS:C1699202",
#           "UMLS:C1504566",
#           "UMLS:C0085594"
#         ],
#         "omnicorp_article_count": 270,
#         "syndromic_disease": true,
#         "synonyms": [],
#         "name": "periodic fever syndrome"
#       },
#       {
#         "id": "MONDO:0021113",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "NCIT:C50594",
#           "MEDDRA:10038678",
#           "UMLS:C0858971",
#           "SNOMEDCT:31515003",
#           "SNOMEDCT:80954004",
#           "MESH:D007040",
#           "HP:0002093",
#           "SNOMEDCT:15993004",
#           "UMLS:C4020855",
#           "MEDDRA:10038695",
#           "MEDDRA:10009126",
#           "MESH:D012131",
#           "HP:0002791",
#           "NCIT:C116314",
#           "SNOMEDCT:409623005",
#           "UMLS:C4087530",
#           "UMLS:C1145670",
#           "EFO:0009686",
#           "UMLS:C3203358",
#           "MONDO:0021113",
#           "UMLS:C0264492",
#           "UMLS:C0398353",
#           "UMLS:C0948755",
#           "SNOMEDCT:709109004",
#           "MEDDRA:10021133",
#           "UMLS:C3805211",
#           "SNOMEDCT:409622000",
#           "HP:0002878",
#           "UMLS:C0035229",
#           "UMLS:C4324356",
#           "UMLS:C2363912",
#           "NCIT:C26872",
#           "UMLS:C0235063",
#           "DOID:11162",
#           "SNOMEDCT:39871006"
#         ],
#         "omnicorp_article_count": 25204,
#         "synonyms": [],
#         "name": "respiratory failure"
#       },
#       {
#         "id": "MONDO:0004730",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "UMLS:C0751513",
#           "SNOMEDCT:62415009",
#           "SNOMEDCT:229751001",
#           "SNOMEDCT:69577009",
#           "HP:0000750",
#           "UMLS:C0233728",
#           "MEDDRA:10013931",
#           "HP:0002167",
#           "SNOMEDCT:29164008",
#           "UMLS:C4280574",
#           "UMLS:C0009090",
#           "UMLS:C0042940",
#           "MESH:D013064",
#           "SNOMEDCT:50219008",
#           "UMLS:C0542257",
#           "UMLS:C1527344",
#           "UMLS:C0019825",
#           "MEDDRA:10024796",
#           "UMLS:C0858568",
#           "UMLS:C3248383",
#           "UMLS:C1854348",
#           "UMLS:C3495145",
#           "UMLS:C0454644",
#           "HP:0001609",
#           "HP:0001618",
#           "MESH:D006685",
#           "UMLS:C0857508",
#           "MEDDRA:10013952",
#           "SNOMEDCT:47004009",
#           "UMLS:C0860619",
#           "HP:0002465",
#           "UMLS:C0233726",
#           "UMLS:C0751514",
#           "NCIT:C86950",
#           "SNOMEDCT:63416000",
#           "UMLS:C0860617",
#           "UMLS:C0454655",
#           "SNOMEDCT:449191001",
#           "SNOMEDCT:37732008",
#           "UMLS:C0860618",
#           "UMLS:C1527347",
#           "UMLS:C0855216",
#           "MESH:D007805",
#           "UMLS:C0541975",
#           "MONDO:0004730",
#           "UMLS:C4728001",
#           "UMLS:C3854685",
#           "UMLS:C0023014",
#           "UMLS:C0751201",
#           "SNOMEDCT:16617009",
#           "UMLS:C0854299",
#           "NCIT:C5041",
#           "UMLS:C0858567",
#           "DOID:92",
#           "UMLS:C0860616",
#           "UMLS:C0751512",
#           "UMLS:C3854612",
#           "UMLS:C0856983",
#           "UMLS:C1168248",
#           "UMLS:C1848207",
#           "UMLS:C0233715",
#           "MEDDRA:10041466",
#           "UMLS:C0037822",
#           "NCIT:C47813",
#           "SNOMEDCT:229721007",
#           "SNOMEDCT:162294008",
#           "UMLS:C0241210",
#           "UMLS:C0859023",
#           "UMLS:C0023012"
#         ],
#         "omnicorp_article_count": 11732,
#         "psychiatric_disorder": true,
#         "synonyms": [
#           "speech impediment or impairment"
#         ],
#         "name": "speech disorder"
#       },
#       {
#         "id": "MONDO:0004900",
#         "type": [
#           "named_thing",
#           "biological_entity",
#           "disease",
#           "disease_or_phenotypic_feature"
#         ],
#         "equivalent_identifiers": [
#           "NCIT:C118255",
#           "DOID:9847",
#           "UMLS:C0476207",
#           "UMLS:C0522359",
#           "MESH:D014717",
#           "SNOMEDCT:399153001",
#           "UMLS:C0220870",
#           "UMLS:C0857226",
#           "UMLS:C0042571",
#           "UMLS:C0012833",
#           "SNOMEDCT:248223005",
#           "UMLS:C0857314",
#           "SNOMEDCT:386705008",
#           "UMLS:C0522351",
#           "MEDDRA:10047340",
#           "UMLS:C0857087",
#           "MONDO:0004900",
#           "SNOMEDCT:103284002",
#           "SNOMEDCT:63024004",
#           "UMLS:C0155501",
#           "UMLS:C0853898",
#           "UMLS:C0581879",
#           "UMLS:C0234757",
#           "SNOMEDCT:50438001",
#           "SNOMEDCT:50041000",
#           "SNOMEDCT:315018008",
#           "HP:0002321",
#           "NCIT:C38057",
#           "HP:0010532",
#           "UMLS:C3854599",
#           "UMLS:C0852858",
#           "UMLS:C0413281",
#           "SNOMEDCT:399090003",
#           "UMLS:C0149746",
#           "UMLS:C0549239",
#           "MESH:D004244",
#           "SNOMEDCT:51568001",
#           "UMLS:C0234750",
#           "UMLS:C0271487",
#           "SNOMEDCT:162271007",
#           "SNOMEDCT:103292006",
#           "SNOMEDCT:103290003",
#           "UMLS:C0522357",
#           "UMLS:C0751573",
#           "UMLS:C0522349",
#           "UMLS:C0857011",
#           "MEDDRA:10013573",
#           "SNOMEDCT:404640003",
#           "UMLS:C1739421",
#           "SNOMEDCT:103282003",
#           "NCIT:C37943",
#           "SNOMEDCT:271789005",
#           "SNOMEDCT:87118001"
#         ],
#         "omnicorp_article_count": 195,
#         "synonyms": [],
#         "name": "peripheral vertigo"
#       }
#     ],
#     "edges": [
#       {
#         "id": "f7ba96a2d5c606323e97d07af7eaa18b",
#         "source_id": "MONDO:0100096",
#         "target_id": "NCBITaxon:2697049",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 2972.641941068292,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.79813
#         ]
#       },
#       {
#         "id": "aff80436570aaf17f95b5acf1c5c0f7b",
#         "source_id": "CHEBI:4975",
#         "target_id": "NCBITaxon:2697049",
#         "type": "in_clinical_trial_for",
#         "relation_label": "in_clinical_trial_for",
#         "weight": 1,
#         "rectified": true,
#         "edge_source": "https://www.drugbank.ca/covid-19",
#         "relation": "in_clinical_trial_for",
#         "predicate_id": "ROBOKOVID:in_clinical_trial_for",
#         "source_database": "drugbank",
#         "count": 1
#       },
#       {
#         "id": "2280d6cddf5f10a8fd58de70f404b987",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0056821",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 0.43356351282442374,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.7023969
#         ]
#       },
#       {
#         "id": "14174cce99ff32ab8c288ae1ef54257f",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0056821",
#         "type": "causes_adverse_event",
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "prr": 1.9620799999999998,
#         "weight": 1,
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "case_count": 20,
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "publications": [],
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "ror": 1.9622099999999998,
#         "ctime": [
#           1595082617.1515436
#         ]
#       },
#       {
#         "id": "be11439ec57dcefc9f15abe6d1e762b9",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0019737",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 0.2317097301209472,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.7003188
#         ]
#       },
#       {
#         "id": "812246ae2940eeefbd72ab73666c01fe",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0019737",
#         "type": "causes_adverse_event",
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "prr": 1.7465700000000002,
#         "weight": 1,
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "case_count": 39,
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "publications": [],
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "ror": 1.7467599999999999,
#         "ctime": [
#           1595082617.1429114
#         ]
#       },
#       {
#         "id": "653fde0eee33086441d5077a731d974b",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0015796",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 2.4819251004707166,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.7007806
#         ]
#       },
#       {
#         "id": "c303bbb38a2ec460a39ed06817d03073",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0015796",
#         "type": "causes_adverse_event",
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "prr": 3.40205,
#         "weight": 1,
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "case_count": 7,
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "publications": [],
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "ror": 3.40217,
#         "ctime": [
#           1595082617.1714506
#         ]
#       },
#       {
#         "id": "7c7423ae1957fd581b156b0421d23294",
#         "source_id": "MONDO:0100096",
#         "target_id": "NCBIGene:7124",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 0.28975843838407,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.5879529
#         ]
#       },
#       {
#         "id": "60c62cc42ccdd831a8a428633584aa73",
#         "source_id": "CHEBI:4975",
#         "target_id": "NCBIGene:7124",
#         "type": "increases_secretion_of",
#         "relation_label": [
#           "increases secretion of",
#           "increases secretion of"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "ctd.gene_to_drug_expanded",
#           "ctd.drug_to_gene_expanded"
#         ],
#         "taxon": "taxon:ncbitaxon:10116",
#         "publications": [
#           "PMID:17698507"
#         ],
#         "relation": [
#           "CTD:increases_secretion_of",
#           "CTD:increases_secretion_of"
#         ],
#         "predicate_id": "biolink:increases_secretion_of",
#         "source_database": [
#           "ctd",
#           "ctd"
#         ],
#         "description": "increases secretion of",
#         "ctime": [
#           1585074891.331755,
#           1593820253.5950353
#         ]
#       },
#       {
#         "id": "eb2b32c3a22ebcefac4d52819d41db51",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0005478",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 0.2899790346415031,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.586854
#         ]
#       },
#       {
#         "id": "7325ed3030aa9e947dd4064104317cfc",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005478",
#         "type": "contributes_to",
#         "relation_label": [
#           "marker_mechanism"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "ctd.disease_to_chemical"
#         ],
#         "relation": [
#           "CTD:marker_mechanism"
#         ],
#         "publications": [
#           "PMID:19358226"
#         ],
#         "predicate_id": "biolink:contributes_to",
#         "source_database": [
#           "ctd"
#         ],
#         "ctime": [
#           1585042796.1710408
#         ]
#       },
#       {
#         "id": "cc99bb33ef8f58c50731d908ae6e750d",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0005478",
#         "type": "causes_adverse_event",
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "prr": 2.45513,
#         "weight": 1,
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "case_count": 86,
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "publications": [],
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "ror": 2.4559599999999997,
#         "ctime": [
#           1595082617.1368022
#         ]
#       },
#       {
#         "id": "109061a2db0cad5009e55fc1cab09575",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0004652",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 0.5380427775446814,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.466953
#         ]
#       },
#       {
#         "id": "ec2db97f8fc49b086acffa6f4f22dbc8",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0004652",
#         "type": "causes_adverse_event",
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "prr": 3.56028,
#         "weight": 1,
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "case_count": 86,
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "publications": [],
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "ror": 3.5617400000000004,
#         "ctime": [
#           1595082617.1368558
#         ]
#       },
#       {
#         "id": "c952240b0e55a98a7d4eb53656b348f1",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0002258",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 8.500365898189639,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.468371
#         ]
#       },
#       {
#         "id": "4cf89334ad046b12f517e13367c341bd",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0002258",
#         "type": "prevents",
#         "relation_label": [
#           "prevents"
#         ],
#         "prr": 0.69686,
#         "weight": 1,
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "case_count": 129,
#         "relation": [
#           "RO:0002599"
#         ],
#         "publications": [],
#         "predicate_id": "biolink:prevents",
#         "source_database": [
#           "mychem"
#         ],
#         "ror": 0.6966,
#         "ctime": [
#           1595082617.1346278
#         ]
#       },
#       {
#         "id": "a9c76d8e36531364d25cb3f83572c806",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0001208",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 2.1990756687937174,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.4688883
#         ]
#       },
#       {
#         "id": "3784d2f2916dc24cfda753828b01269d",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0001208",
#         "type": "causes_adverse_event",
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "prr": 1.72403,
#         "weight": 1,
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "case_count": 121,
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "publications": [],
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "ror": 1.7246099999999998,
#         "ctime": [
#           1595082617.1350465
#         ]
#       },
#       {
#         "id": "5036689d55b8f9f9e8d2c35fdfb3e258",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0045057",
#         "type": "related_to",
#         "relation_label": [
#           "related_to"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "cord19_scigraph_v12"
#         ],
#         "relation": [
#           "SEMMEDDB:ASSOCIATED_WITH"
#         ],
#         "publications": [],
#         "predicate_id": "SEMMEDDB:ASSOCIATED_WITH",
#         "num_publications": 2.3080327136180716,
#         "enrichment_p": 0.0,
#         "source_database": [
#           "cord19_scigraph_v12"
#         ],
#         "ctime": [
#           1597668521.4670088
#         ]
#       },
#       {
#         "id": "9f4df0444db2a3ffc09c25e8b0713578",
#         "source_id": "MONDO:0100096",
#         "target_id": "MONDO:0045057",
#         "type": "has_phenotype",
#         "relation_label": [
#           "has_phenotype"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "covid_phenotypes_csv"
#         ],
#         "relation": [
#           "RO:0002200"
#         ],
#         "publications": [],
#         "predicate_id": "RO:0002200",
#         "source_database": [
#           "covid_phenotypes_csv"
#         ],
#         "notes": "Covid symptom tracker",
#         "ctime": [
#           1597669781.6380565
#         ]
#       },
#       {
#         "id": "908ca5052b017f4ea79f769b5c3a5897",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0045057",
#         "type": "contributes_to",
#         "relation_label": [
#           "marker_mechanism"
#         ],
#         "weight": 1,
#         "edge_source": [
#           "ctd.disease_to_chemical"
#         ],
#         "relation": [
#           "CTD:marker_mechanism"
#         ],
#         "publications": [
#           "PMID:3243179",
#           "PMID:9545163"
#         ],
#         "predicate_id": "biolink:contributes_to",
#         "source_database": [
#           "ctd"
#         ],
#         "ctime": [
#           1585042672.8032074
#         ]
#       },
#       {
#         "id": "1e4dfcec8da6409799fb897f6e02a746",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0045057",
#         "type": "causes_adverse_event",
#         "relation_label": [
#           "causes_or_contributes_to"
#         ],
#         "prr": 2.34115,
#         "weight": 1,
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "case_count": 366,
#         "relation": [
#           "Aeolus:0000001"
#         ],
#         "publications": [],
#         "predicate_id": "biolink:causes_adverse_event",
#         "source_database": [
#           "mychem"
#         ],
#         "ror": 2.34441,
#         "ctime": [
#           1595082617.1313725
#         ]
#       },
#       {
#         "id": "8183f213914fbca4a1ada57f34367e93",
#         "source_id": "CHEBI:4975",
#         "target_id": "MONDO:0045057",
#         "type": "prevents",
#         "relation_label": [
#           "prevents"
#         ],
#         "prr": 0.76758,
#         "weight": 1,
#         "edge_source": [
#           "mychem.get_adverse_events"
#         ],
#         "case_count": 424,
#         "relation": [
#           "RO:0002599"
#         ],
#         "publications": [],
#         "predicate_id": "biolink:prevents",
#         "source_database": [
# ...
#           "kg_id": "4748925d-97ee-47ef-b576-9ac8a18f68f3",
#           "weight": 0.011878609336186896
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.11218842883555613
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0015137"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "2c23784201bbecd03ac2d95c7670b817",
#           "weight": 0.9999958711504491
#         },
#         {
#           "qg_id": "ab",
#           "kg_id": "4b5cc0ba33025b8d27e1ea9c61d24545",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "2df290232bf3d30a27ad874836d05262",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.11060164282263675
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005249"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "c7ce253a2de06705ce6c6c9e2155ab4a",
#           "weight": 0.9999999999954481
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "da825870d445b043d8c03cde137e1499",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "s21",
#           "kg_id": "e00f8506-436a-42c8-a5c7-365037796738",
#           "weight": 0.0038342811209324257
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.10685131518209905
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "NCBITaxon:2697049"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "f7ba96a2d5c606323e97d07af7eaa18b",
#           "weight": 1.0
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "aff80436570aaf17f95b5acf1c5c0f7b",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.1056624327025936
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0002258"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "c952240b0e55a98a7d4eb53656b348f1",
#           "weight": 0.9892286174666232
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "4cf89334ad046b12f517e13367c341bd",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "s15",
#           "kg_id": "24f219f5-6af5-443c-bb72-0bfc6c1e497b",
#           "weight": 0.000702274323792107
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.105637143942387
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0021113"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "6b637092c75966e1c35ee55ef62219fc",
#           "weight": 0.9933746758258188
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "a72584a4e86423d6d94314f0bce9ddc5",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.10551371811305281
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0024355"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "c6ad4bcfc2f9404760353d0c6e14a757",
#           "weight": 0.982290959293364
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "1846fe0ab4733cbf57cf1e1c450a555a",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.10526140474372304
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "NCBIGene:7124"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "7c7423ae1957fd581b156b0421d23294",
#           "weight": 0.34012698346324877
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "60c62cc42ccdd831a8a428633584aa73",
#           "weight": 0.4999999999999998
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.10121296844351615
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0015796"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "653fde0eee33086441d5077a731d974b",
#           "weight": 0.7426315349333443
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "c303bbb38a2ec460a39ed06817d03073",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.09845206556542106
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0001208"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "a9c76d8e36531364d25cb3f83572c806",
#           "weight": 0.7057353164939839
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "3784d2f2916dc24cfda753828b01269d",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.09710599603430226
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0019810"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "0c55c26d87be113f70e4dda7cbd75d85",
#           "weight": 0.5655810872611449
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "360a39b818b2e4df83794bc95e083724",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "s39",
#           "kg_id": "45b33a26-77da-40d9-8342-9b01cd6c050c",
#           "weight": 0.005649926783491965
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.09219860414067288
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0001243"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "94c0e06a30513062fcee89e3ca7363bb",
#           "weight": 0.573476543904875
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "5230997850fea7af82071c758253bfd6",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "s31",
#           "kg_id": "2e047b83-c14d-4cf2-b675-37ab1fb2f21e",
#           "weight": 0.0017703807035425179
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.09172115804318436
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0004730"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "04b388385c74f1f389d8edc8a2b76707",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "52a00428d863733171ef71ec9f0de00b",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "c9605cdaf3cf404cd43bb7b2f70167f5",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.08931639747704098
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0004995"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "cee8f061f83713bca61cc0f7ca083f4e",
#           "weight": 0.528807115838255
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "84aa4a49db52be6a1be71060f32b219c",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "s37",
#           "kg_id": "738c5812-b941-4074-a46b-263313ba0a4a",
#           "weight": 0.0
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.0889189317800707
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0003785"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "d1b2d3715085b8d8fade58301abb1dc2",
#           "weight": 0.4351902913761012
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "1173aa8a4bf2e0a4d42adcad4fbec00a",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "s23",
#           "kg_id": "0ad26f31-a0f2-429f-9db1-9cde7bbc7e3d",
#           "weight": 0.0003070707819303742
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.08297895596299835
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0004652"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "109061a2db0cad5009e55fc1cab09575",
#           "weight": 0.39897406432070515
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "ec2db97f8fc49b086acffa6f4f22dbc8",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.08014773608013241
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0056821"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "2280d6cddf5f10a8fd58de70f404b987",
#           "weight": 0.374573621530218
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "14174cce99ff32ab8c288ae1ef54257f",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.07810360754058907
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005113"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "bbaaff34c1aa38d09cbb1ea3b971c359",
#           "weight": 0.34269650956680997
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "6d7efc3a7025d38ea53fc918545ff336",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "s41",
#           "kg_id": "26158701-b3ad-4deb-aed1-c5dbdf77a271",
#           "weight": 0.0
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.07518701326067975
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005263"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "9cafac13235b8ae745a7930a4c9436cf",
#           "weight": 0.33069381641594275
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "68727deb8a51a89077d0dbf040f34025",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.07400833196170736
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0019737"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "be11439ec57dcefc9f15abe6d1e762b9",
#           "weight": 0.32595248119313136
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "812246ae2940eeefbd72ab73666c01fe",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.07352959924631997
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0005265"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "7f29d713370c8aacab232c743ee3987a",
#           "weight": 0.30409428907913316
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "d573cb39419143de1dc2d84a0206eb30",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "s35",
#           "kg_id": "d6502b13-2264-46eb-b61c-4f86425444bb",
#           "weight": 0.0
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.07121995251702669
#     },
#     {
#       "node_bindings": [
#         {
#           "qg_id": "a",
#           "kg_id": "MONDO:0100096"
#         },
#         {
#           "qg_id": "b",
#           "kg_id": "MONDO:0004900"
#         },
#         {
#           "qg_id": "c",
#           "kg_id": "CHEBI:4975"
#         }
#       ],
#       "edge_bindings": [
#         {
#           "qg_id": "ab",
#           "kg_id": "a0ab13c777e2d23b0ea6f82a2d06dd88",
#           "weight": 0.2679491924311228
#         },
#         {
#           "qg_id": "bc",
#           "kg_id": "97ba863e0634a258a7bd4f13f5c2154b",
#           "weight": 0.2679491924311228
#         }
#       ],
#       "extra_nodes": null,
#       "extra_edges": null,
#       "score": 0.06698729810778069
#     }
#   ]
# }

# %%
with open('famcov.json','w') as outf:
    json.dump(robokop_result,outf,indent=2)

# %% [markdown]
# ## Coalesce Answers by Property

# %%
url = 'https://answercoalesce.renci.org/coalesce'
params = {'method':'property'}
p_r = requests.post(url,json=robokop_result,params=params)
print(p_r.status_code)
property_result = p_r.json()
# Out:
# 200

# %%
property_result['results']
# Out:
# []

# %%
results = property_result['results']
num_grouped=[]
p_values=[]
properties=[]
for result in results:
    chemnode = result['node_bindings'][2]
    for p,prop in zip(chemnode['p_values'],chemnode['properties']):
        num_grouped.append(len(chemnode['kg_id']))
        p_values.append(p)
        properties.append(prop)
df = pd.DataFrame( {'NumberGrouped': num_grouped, 'p_value':p_values, 'PropertyGroup':properties})
df.sort_values(by='p_value',inplace=True)
df
# Out:
# Empty DataFrame
# Columns: [NumberGrouped, p_value, PropertyGroup]
# Index: []

# %% [markdown]
# ## Coalesce Answers by Ontology

# %%
url = 'https://answercoalesce.renci.org/coalesce'
params = {'method':'ontology'}
o_r = requests.post(url,json=robokop_result,params=params)
print(o_r.status_code)
ontology_result = o_r.json()
print( len(ontology_result['results']))
# Out:
# 200
# 1

# %%
results = ontology_result['results']
for result in results:
    print('\n================')
    chemnode = result['node_bindings'][1]
    sclass = chemnode['superclass']
    label = getlabel(sclass)
    nodes = chemnode['kg_id']
    labels = {x: f'{getlabel(x)}' for x in nodes }
    for x in nodes:
        print(f'{labels[x]} ({x})')
    print('----have superclass----')
    print(f'{label} ({sclass})')
# Out:
# ================
# respiratory failure (MONDO:0021113)
# acute lung injury (MONDO:0015796)
# bronchiolitis obliterans organizing pneumonia (MONDO:0056821)
# bacterial pneumonia (MONDO:0004652)
# pneumonia (MONDO:0005249)
# acute respiratory failure (MONDO:0001208)
# ----have superclass----
# lung disease (MONDO:0005275)

# %%
from copy import deepcopy
onrd = deepcopy(ontology_result)
for n in onrd['query_graph']['nodes']:
    if 'curie' in n and n['curie'] is None:
        del[n['curie']]
for n in onrd['knowledge_graph']['nodes']:
    if 'name' not in n:
        label = getlabel(n['id'])
        n['name'] = label
for e in onrd['knowledge_graph']['edges']:
    e['id'] = str(e['id'])
for r in onrd['results']:
    for eb in r['edge_bindings']:
        eb['kg_id'] = [ str(x) for x in eb['kg_id']]
#react_component = GammaViewer(props={"data":onrd})
#display(react_component)

# %%
with open('ontology_output.json.txt','w') as outf:
    json.dump(onrd,outf,indent=2)

# %% [markdown]
# ## Coalescence by Graph

# %% [markdown]
# Coalescence by graph is similar to coalescence by ontology, but the new relationships can be more general than `is_a`.

# %%
url = 'https://answercoalesce.renci.org/coalesce'
params = {'method':'graph'}
g_r = requests.post(url,json=robokop_result,params=params)
print(g_r.status_code)
graph_result = g_r.json()
print( len(graph_result['results']))
# Out:
# 500
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-42-aaa5afbb88fc> in <module>
#       4 g_r = requests.post(url,json=robokop_result,params=params)
#       5 print(g_r.status_code)
# ----> 6 graph_result = g_r.json()
#       7 print( len(graph_result['results']))
#       8
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\AppData\Local\Programs\Python\Python38\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\AppData\Local\Programs\Python\Python38\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\AppData\Local\Programs\Python\Python38\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 5 (char 5)

# %%
from copy import deepcopy
gd = deepcopy(graph_result)
for n in gd['query_graph']['nodes']:
    if 'curie' in n and n['curie'] is None:
        del[n['curie']]
for n in gd['knowledge_graph']['nodes']:
    if 'name' not in n:
        label = getlabel(n['id'])
        n['name'] = label
for e in gd['knowledge_graph']['edges']:
    e['id'] = str(e['id'])
for r in gd['results']:
    for eb in r['edge_bindings']:
        eb['kg_id'] = [ str(x) for x in eb['kg_id']]
#react_component = GammaViewer(props={"data":gd})
#display(react_component)

# %%
def draw_one(results,rnum):
    g = deepcopy(results)
    g['results']=[g['results'][rnum]]
    kgs = set()
    for nb in g['results'][0]['node_bindings']:
        for kgid in nb['kg_id']:
            kgs.add(kgid)
    kg = g['knowledge_graph']
    kg['nodes'] = [n for n in kg['nodes'] if n['id'] in kgs ]
    kg['edges'] = [e for e in kg['edges'] if (e['source_id'] in kgs) and (e['target_id'] in kgs)]
#    react_component = GammaViewer(props={"data":g})
#    display(react_component)

# %%
draw_one(gd,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c1d56dc37953> in <module>
# ----> 1 draw_one(gd,3)
#       2
#
# NameError: name 'gd' is not defined

# %%
gd

# %%
gd['results'][1]

# %%
names = {}
for node in gd['knowledge_graph']['nodes']:
    names[node['id']] = node['name']
r=0
for result in gd['results']:
    for nb in result['node_bindings']:
        if nb['qg_id'].startswith('extra'):
            kgid = nb['kg_id'][0]
            print(r, kgid, names[kgid])
    r += 1

# %%
def create_threehop_message():
    query_graph = {
    "nodes": [
        {
            #Covid-19
            "id": "a",
            "type": "disease",
            "curie": "MONDO:0100096"
        },
        {
            "id": "b",
            "type": "gene"
        },
        {
            "id": "c",
            "type": "named_thing"
        },
        {
            #Famotidine
            "id": "d",
            "type": "chemical_substance",
            "curie": "CHEBI:4975"
        }
    ],
    "edges": [
        {
            "id": "ab",
            "source_id": "a",
            "target_id": "b"
        },
        {
            "id": "bc",
            "source_id": "c",
            "target_id": "b"
        },
        {
            "id": "cd",
            "source_id": "c",
            "target_id": "d"
        }
    ]
    }
    message = {"message": {"query_graph": query_graph,
                           'results':[{"node_bindings": [],"edge_bindings": []}]}}
    return message

# %%
message3 = create_threehop_message()
robokop_result2 = robokop.pipeline(message3,full=False)

# %%
print (len(robokop_result2['results']))

# %%
params = {'method':'graph'}
g_r2 = requests.post(url,json=robokop_result2,params=params)
print(g_r2.status_code)
graph_result2 = g_r2.json()
print( len(graph_result2['results']))

# %%
with open('bigger.json','w') as outf:
    json.dump(robokop_result2,outf,indent=2)
